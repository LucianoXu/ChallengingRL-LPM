# %%
# !pip install python-mnist
# Out:
# Collecting python-mnist
#   Downloading python_mnist-0.7-py2.py3-none-any.whl.metadata (3.5 kB)
# Downloading python_mnist-0.7-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: python-mnist
# Successfully installed python-mnist-0.7

# %% [markdown]
# ### My code

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from mnist.loader import MNIST
from tqdm import tqdm
from collections import deque
import copy

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load MNIST data
try:
    mndata = MNIST("data")
    x_train_data, y_train_data = mndata.load_training()
    x_test_data, y_test_data = mndata.load_testing()
    print("MNIST data loaded successfully")
except Exception as e:
    print(f"Error loading MNIST data: {e}")
    print("Make sure the 'mnist' package is installed and the data directory exists")
    print("You can install it with: pip install python-mnist")
    raise

# Define Noisy MNIST Environment
class NoisyMnistEnv:
    def __init__(self, split, input_number_min, input_number_max, batch_size=32, seed=0):
        self.seed = seed
        np.random.seed(seed)
        self.split = split
        if self.split == "train":
            self.x, self.y = x_train_data, y_train_data
        elif self.split == "test":
            self.x, self.y = x_test_data, y_test_data
        self.batch_size = batch_size
        self.input_number_min = input_number_min
        self.input_number_max = input_number_max

    def step(self):
        x_arr = np.zeros((self.batch_size, 28 * 28))
        y_arr = np.zeros((self.batch_size, 28 * 28))

        for i in range(self.batch_size):
            input_number = np.random.randint(self.input_number_min, self.input_number_max)
            if input_number == 0:
                output_number = 0
            if input_number == 1:
                output_number = np.random.randint(2, 10)
            input_data = self.get_random_sample_of_number(input_number)
            if input_number == 1:
                output_data = self.get_random_sample_of_number(output_number)
            elif input_number == 0:
                output_data = input_data
            x_arr[i] = np.array(input_data)
            y_arr[i] = np.array(output_data)
        return x_arr, y_arr

    def get_random_sample_of_number(self, number):
        random_num = np.random.randint(0, len(self.y) - 1)
        if self.y[random_num] == number:
            return self.x[random_num]
        else:
            return self.get_random_sample_of_number(number)

# Define MSE Network
class MSENet(nn.Module):
    def __init__(self):
        super(MSENet, self).__init__()
        self.linear_1 = nn.Linear(28 * 28, 784)
        self.linear_2 = nn.Linear(784, 784)
        self.linear_3 = nn.Linear(784, 784)
        self.linear_4 = nn.Linear(784 * 2, 28 * 28)

    def forward(self, input_x):
        x = F.relu(self.linear_1(input_x))
        x = F.relu(self.linear_2(x))
        x = F.relu(self.linear_3(x))
        x = torch.cat((input_x, x), dim=1)
        x = self.linear_4(x)
        return x

# Define Aleatoric Network
class AleatoricNet(nn.Module):
    def __init__(self):
        super(AleatoricNet, self).__init__()
        self.linear_1 = nn.Linear(28 * 28, 784)
        self.linear_2 = nn.Linear(784, 784)
        self.linear_3_mu = nn.Linear(784, 784)
        self.linear_4_mu = nn.Linear(784 * 2, 28 * 28)
        self.linear_3_sigma = nn.Linear(784, 784)
        self.linear_4_sigma = nn.Linear(784, 28 * 28)

    def forward(self, input_x):
        x = F.relu(self.linear_1(input_x))
        x = F.relu(self.linear_2(x))
        mu = F.relu(self.linear_3_mu(x))
        mu = torch.cat((input_x, mu), dim=1)
        mu = self.linear_4_mu(mu)
        log_sigma = F.relu(self.linear_3_sigma(x))
        log_sigma = self.linear_4_sigma(log_sigma)
        return mu, log_sigma

# Define Uncertainty Predictor Network
class UncertaintyPredictor(nn.Module):
    def __init__(self):
        super(UncertaintyPredictor, self).__init__()
        self.linear_1 = nn.Linear(28 * 28, 256)
        self.linear_2 = nn.Linear(256, 128)
        self.linear_3 = nn.Linear(128, 64)
        self.linear_4 = nn.Linear(64, 28 * 28)

    def forward(self, input_x):
        x = F.relu(self.linear_1(input_x))
        x = F.relu(self.linear_2(x))
        x = F.relu(self.linear_3(x))
        log_var = self.linear_4(x)
        return log_var

# Experience Buffer for uncertainty predictor
class ExperienceBuffer:
    def __init__(self, max_size=100):
        self.buffer = deque(maxlen=max_size)

    def add(self, input_data, error):
        self.buffer.append((input_data, error))

    def sample(self, batch_size):
        if len(self.buffer) < batch_size:
            batch_size = len(self.buffer)
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        inputs = []
        errors = []
        for idx in indices:
            inp, err = self.buffer[idx]
            inputs.append(inp)
            errors.append(err)
        return torch.stack(inputs), torch.stack(errors)

    def __len__(self):
        return len(self.buffer)

# Base Experiment Class
class BaseExperiment:
    def __init__(self, training_steps, checkpoint_loss, lr, device, seed=42):
        self.training_steps = training_steps
        self.checkpoint_loss = checkpoint_loss
        self.lr = lr
        self.device = device
        self.seed = seed

        # Set random seeds for reproducibility
        np.random.seed(seed)
        torch.manual_seed(seed)
        if torch.cuda.is_available():
            torch.cuda.manual_seed(seed)

        # Initialize environments with seed
        self.env_train = NoisyMnistEnv("train", 0, 2, batch_size=32, seed=seed)
        self.env_test_zeros = NoisyMnistEnv("test", 0, 1, batch_size=32, seed=seed+1000)
        self.env_test_ones = NoisyMnistEnv("test", 1, 2, batch_size=32, seed=seed+2000)

        self.reset_loss_buffers()

    def reset_loss_buffers(self):
        self.loss_list = []
        self.loss_buffer = []
        self.loss_list_0 = []
        self.loss_list_1 = []
        self.loss_buffer_0 = []
        self.loss_buffer_1 = []

    def preprocess_batch(self, data, target):
        data /= 255
        target /= 255
        return data, target

    def get_batch(self, env):
        data, target = env.step()
        data, target = self.preprocess_batch(data, target)
        data = torch.from_numpy(data).float().to(self.device)
        target = torch.from_numpy(target).float().to(self.device)
        return data, target

    def run_experiment(self):
        for update in tqdm(range(int(self.training_steps)), desc=f"Training {self.__class__.__name__} (seed={self.seed})"):
            self.train_step(update)
            self.eval_step("ones", update)
            self.eval_step("zeros", update)
        return self.loss_list_0, self.loss_list_1

# MSE Baseline Experiment
class MSEExperiment(BaseExperiment):
    def __init__(self, training_steps, checkpoint_loss, lr, device, seed=42):
        super().__init__(training_steps, checkpoint_loss, lr, device, seed)
        self.model = MSENet().to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)

    def compute_loss_and_reward(self, prediction, target):
        loss = F.mse_loss(prediction, target)
        reward = loss  # Intrinsic reward is the prediction error
        return loss, reward

    def train_step(self, update):
        update += 1
        self.model.train()
        data, target = self.get_batch(self.env_train)
        self.optimizer.zero_grad()
        output = self.model(data)
        loss, reward = self.compute_loss_and_reward(output, target)
        loss.backward()
        self.optimizer.step()
        self.loss_buffer.append(reward)
        if update % self.checkpoint_loss == 0:
            self.loss_list.append(
                torch.mean(torch.stack(self.loss_buffer)).detach().cpu().numpy()
            )
            self.loss_buffer = []

    def eval_step(self, ones_or_zeros, update):
        update += 1
        self.model.eval()
        if ones_or_zeros == "ones":
            env = self.env_test_ones
            loss_buffer = self.loss_buffer_1
            loss_list = self.loss_list_1
        elif ones_or_zeros == "zeros":
            env = self.env_test_zeros
            loss_buffer = self.loss_buffer_0
            loss_list = self.loss_list_0

        data, target = self.get_batch(env)
        with torch.no_grad():
            output = self.model(data)
            loss, reward = self.compute_loss_and_reward(output, target)
        loss_buffer.append(reward)

        if update % self.checkpoint_loss == 0:
            loss_list.append(
                torch.mean(torch.stack(loss_buffer)).detach().cpu().numpy()
            )
            loss_buffer.clear()

# AMA Experiment
class AMAExperiment(BaseExperiment):
    def __init__(self, training_steps, checkpoint_loss, lr, device, lambda_param=1.0, eta_param=1.0, seed=42):
        super().__init__(training_steps, checkpoint_loss, lr, device, seed)
        self.model = AleatoricNet().to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.lambda_param = lambda_param
        self.eta_param = eta_param

    def compute_loss_and_reward(self, prediction, target):
        mu, log_sigma = prediction
        mse = F.mse_loss(mu, target, reduction="none")

        # Loss calculation using aleatoric uncertainty formula
        loss = torch.mean(torch.exp(-log_sigma) * mse + log_sigma)

        # Intrinsic reward: MSE - η * exp(log_sigma)
        reward = torch.mean(mse - self.eta_param * torch.exp(log_sigma))

        return loss, reward

    def train_step(self, update):
        update += 1
        self.model.train()
        data, target = self.get_batch(self.env_train)
        self.optimizer.zero_grad()
        output = self.model(data)
        loss, reward = self.compute_loss_and_reward(output, target)
        loss.backward()
        self.optimizer.step()
        self.loss_buffer.append(reward)
        if update % self.checkpoint_loss == 0:
            self.loss_list.append(
                torch.mean(torch.stack(self.loss_buffer)).detach().cpu().numpy()
            )
            self.loss_buffer = []

    def eval_step(self, ones_or_zeros, update):
        update += 1
        self.model.eval()
        if ones_or_zeros == "ones":
            env = self.env_test_ones
            loss_buffer = self.loss_buffer_1
            loss_list = self.loss_list_1
        elif ones_or_zeros == "zeros":
            env = self.env_test_zeros
            loss_buffer = self.loss_buffer_0
            loss_list = self.loss_list_0

        data, target = self.get_batch(env)
        with torch.no_grad():
            output = self.model(data)
            loss, reward = self.compute_loss_and_reward(output, target)
        loss_buffer.append(reward)

        if update % self.checkpoint_loss == 0:
            loss_list.append(
                torch.mean(torch.stack(loss_buffer)).detach().cpu().numpy()
            )
            loss_buffer.clear()

# Uncertainty Predictor Experiment
class UncertaintyPredictorExperiment(BaseExperiment):
    def __init__(self, training_steps, checkpoint_loss, mse_lr, uncertainty_lr, device,
                 max_buffer_size=100, uncertainty_update_freq=10, uncertainty_batch_size=32, eta_param=1.0, seed=42):
        super().__init__(training_steps, checkpoint_loss, mse_lr, device, seed)
        self.mse_model = MSENet().to(device)
        self.uncertainty_model = UncertaintyPredictor().to(device)
        self.mse_optimizer = optim.Adam(self.mse_model.parameters(), lr=mse_lr)
        self.uncertainty_optimizer = optim.Adam(self.uncertainty_model.parameters(), lr=uncertainty_lr)
        self.experience_buffer = ExperienceBuffer(max_size=max_buffer_size)
        self.uncertainty_update_freq = uncertainty_update_freq
        self.uncertainty_batch_size = uncertainty_batch_size
        self.eta_param = eta_param

    def compute_mse_loss(self, prediction, target):
        return F.mse_loss(prediction, target, reduction='none')

    def update_uncertainty_model(self):
        if len(self.experience_buffer) < self.uncertainty_batch_size:
            return
        inputs, errors = self.experience_buffer.sample(self.uncertainty_batch_size)
        epsilon = 1e-6
        log_target = torch.log(errors + epsilon)
        log_variance = self.uncertainty_model(inputs)
        loss = F.mse_loss(log_variance, log_target)
        self.uncertainty_optimizer.zero_grad()
        loss.backward()
        self.uncertainty_optimizer.step()

    def compute_adjusted_reward(self, data, mse):
        with torch.no_grad():
            log_variance = self.uncertainty_model(data)
            variance = torch.exp(log_variance)
            adjusted_reward = - (mse - self.eta_param * variance) * 0.2
            per_sample_adjusted = adjusted_reward.mean()
        return per_sample_adjusted

    def train_step(self, update):
        update += 1
        self.mse_model.train()
        data, target = self.get_batch(self.env_train)
        self.mse_optimizer.zero_grad()
        prediction = self.mse_model(data)
        mse = self.compute_mse_loss(prediction, target)
        per_sample_mse = mse.mean(dim=1, keepdim=True).expand_as(mse)
        loss = mse.mean()
        loss.backward()
        self.mse_optimizer.step()

        # Store experience
        with torch.no_grad():
            for i in range(data.size(0)):
                self.experience_buffer.add(data[i].detach().clone(), per_sample_mse[i].detach().clone())

        # Update uncertainty model
        if update % self.uncertainty_update_freq == 0:
            self.update_uncertainty_model()

        # Compute adjusted reward for logging
        adjusted_reward = self.compute_adjusted_reward(data, mse)
        self.loss_buffer.append(adjusted_reward)

        if update % self.checkpoint_loss == 0:
            self.loss_list.append(
                torch.mean(torch.stack(self.loss_buffer)).cpu().numpy()
            )
            self.loss_buffer = []

    def eval_step(self, ones_or_zeros, update):
        update += 1
        self.mse_model.eval()
        if ones_or_zeros == "ones":
            env = self.env_test_ones
            loss_buffer = self.loss_buffer_1
            loss_list = self.loss_list_1
        elif ones_or_zeros == "zeros":
            env = self.env_test_zeros
            loss_buffer = self.loss_buffer_0
            loss_list = self.loss_list_0

        data, target = self.get_batch(env)
        with torch.no_grad():
            prediction = self.mse_model(data)
            mse = self.compute_mse_loss(prediction, target)
            adjusted_reward = self.compute_adjusted_reward(data, mse)

        loss_buffer.append(adjusted_reward)

        if update % self.checkpoint_loss == 0:
            loss_list.append(adjusted_reward.cpu().numpy())
            loss_buffer.clear()

def run_single_experiment(experiment_class, exp_params, run_id):
    """Run a single experiment with given parameters and run ID for seeding"""
    # Create a unique seed for this run
    seed = 42 + run_id * 1000

    if experiment_class == MSEExperiment:
        experiment = experiment_class(seed=seed, **exp_params)
    elif experiment_class == AMAExperiment:
        experiment = experiment_class(seed=seed, **exp_params)
    elif experiment_class == UncertaintyPredictorExperiment:
        experiment = experiment_class(seed=seed, **exp_params)

    return experiment.run_experiment()

def run_multiple_experiments_and_compare(
    num_runs=5,
    training_steps=600,
    checkpoint_loss=10,
    mse_lr=0.001,
    ama_lr=0.0001,
    uncertainty_mse_lr=0.001,
    uncertainty_lr=0.001,
    lambda_param=1.0,
    eta_param=1.0,
    max_buffer_size=100,
    uncertainty_update_freq=5,
    uncertainty_batch_size=32
):
    """
    Run all three experiments multiple times and plot comparative results with error bars
    """
    print("="*60)
    print(f"RUNNING COMPARATIVE EXPLORATION EXPERIMENTS ({num_runs} runs each)")
    print("="*60)

    # Define experiment parameters
    mse_params = {
        'training_steps': training_steps,
        'checkpoint_loss': checkpoint_loss,
        'lr': mse_lr,
        'device': device
    }

    ama_params = {
        'training_steps': training_steps,
        'checkpoint_loss': checkpoint_loss,
        'lr': 0.0001,
        'device': device,
        'lambda_param': lambda_param,
        'eta_param': eta_param
    }

    uncertainty_params = {
        'training_steps': training_steps,
        'checkpoint_loss': checkpoint_loss,
        'mse_lr': uncertainty_mse_lr,
        'uncertainty_lr': uncertainty_lr,
        'device': device,
        'max_buffer_size': max_buffer_size,
        'uncertainty_update_freq': uncertainty_update_freq,
        'uncertainty_batch_size': uncertainty_batch_size,
        'eta_param': eta_param
    }

    # Storage for results from all runs
    all_results = {
        'mse': {'det': [], 'stoch': []},
        'ama': {'det': [], 'stoch': []},
        'uncertainty': {'det': [], 'stoch': []}
    }

    # Run experiments multiple times
    for run_id in range(num_runs):
        print(f"\n--- Run {run_id + 1}/{num_runs} ---")

        # MSE Experiment
        print(f"Running MSE Baseline (Run {run_id + 1})...")
        mse_det, mse_stoch = run_single_experiment(MSEExperiment, mse_params, run_id)
        all_results['mse']['det'].append(mse_det)
        all_results['mse']['stoch'].append(mse_stoch)

        # AMA Experiment
        print(f"Running AMA (Run {run_id + 1})...")
        ama_det, ama_stoch = run_single_experiment(AMAExperiment, ama_params, run_id)
        all_results['ama']['det'].append(ama_det)
        all_results['ama']['stoch'].append(ama_stoch)

        # Uncertainty Predictor Experiment
        print(f"Running Uncertainty Predictor (Run {run_id + 1})...")
        up_det, up_stoch = run_single_experiment(UncertaintyPredictorExperiment, uncertainty_params, run_id)
        all_results['uncertainty']['det'].append(up_det)
        all_results['uncertainty']['stoch'].append(up_stoch)

    # Process results - find minimum length across all runs and methods
    min_length = float('inf')
    for method in all_results:
        for condition in ['det', 'stoch']:
            for run_data in all_results[method][condition]:
                min_length = min(min_length, len(run_data))

    print(f"\nProcessing results (minimum length: {min_length} points)...")

    # Truncate all results to minimum length and convert to numpy arrays
    processed_results = {}
    for method in all_results:
        processed_results[method] = {}
        for condition in ['det', 'stoch']:
            # Truncate each run to min_length and stack
            truncated_runs = [run_data[:min_length] for run_data in all_results[method][condition]]
            processed_results[method][condition] = np.array(truncated_runs)

    # Calculate means and standard deviations
    stats = {}
    for method in processed_results:
        stats[method] = {}
        for condition in ['det', 'stoch']:
            data = processed_results[method][condition]  # Shape: (num_runs, time_steps)
            stats[method][condition] = {
                'mean': np.mean(data, axis=0),
                'std': np.std(data, axis=0),
                'all_runs': data
            }

    # Generate steps for x-axis (skip first 10 points as in original)
    start_idx = 10
    steps = np.arange(start_idx * checkpoint_loss, min_length * checkpoint_loss, checkpoint_loss)

    # Plotting
    print(f"Creating plots (steps: {len(steps)}, skipping first {start_idx} data points)...")

    # Create comparison plots with error bars
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

    # Colors and labels
    colors = {'mse': 'blue', 'ama': 'green', 'uncertainty': 'red'}
    labels = {'mse': 'MSE', 'ama': 'AMA', 'uncertainty': 'LPM'}

    # Plot deterministic transitions (0→0)
    for method in ['mse', 'ama', 'uncertainty']:
        mean_data = stats[method]['det']['mean'][start_idx:]
        std_data = stats[method]['det']['std'][start_idx:]
        ax1.plot(steps, mean_data, label=labels[method], color=colors[method], linewidth=2)
        ax1.fill_between(steps, mean_data - std_data, mean_data + std_data,
                        color=colors[method], alpha=0.2)

    ax1.set_xlabel('Training Steps')
    ax1.set_ylabel('Intrinsic Reward')
    ax1.set_title('Deterministic Transitions (0→0)')
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    # Plot stochastic transitions (1→{2,...,9})
    for method in ['mse', 'ama', 'uncertainty']:
        mean_data = stats[method]['stoch']['mean'][start_idx:]
        std_data = stats[method]['stoch']['std'][start_idx:]
        ax2.plot(steps, mean_data, label=labels[method], color=colors[method], linewidth=2)
        ax2.fill_between(steps, mean_data - std_data, mean_data + std_data,
                        color=colors[method], alpha=0.2)

    ax2.set_xlabel('Training Steps')
    ax2.set_ylabel('Intrinsic Reward')
    ax2.set_title('Stochastic Transitions (1→{2,...,9})')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f'exploration_methods_comparison_{num_runs}runs.pdf', dpi=300, bbox_inches='tight')
    plt.show()

    plt.style.use('default')
    plt.rcParams.update({
        'font.size': 10,
        'font.family': 'serif',
        'font.serif': ['Times New Roman', 'Times', 'serif'],
        'mathtext.fontset': 'stix',
        'axes.linewidth': 0.8,
        'grid.linewidth': 0.5,
        'lines.linewidth': 1.5,
    })


    # Plot methods with distinguishable styles
    fig, ax = plt.subplots(figsize=(7, 5.2))

    # Plot methods with distinguishable styles
    line_styles = ['-', '--']
    line_labels = ['Det.', 'Stoch.']

    for method in ['mse', 'ama', 'uncertainty']:
        for i, env_type in enumerate(['det', 'stoch']):
            mean_data = stats[method][env_type]['mean'][start_idx:]
            std_data = stats[method][env_type]['std'][start_idx:]

            label = f'{labels[method]} ({line_labels[i]})'

            ax.plot(steps, mean_data,
                   label=label,
                   color=colors[method],
                   linestyle=line_styles[i],
                   linewidth=1.8)

            ax.fill_between(steps, mean_data - std_data, mean_data + std_data,
                           color=colors[method], alpha=0.15)

    # Labels with appropriate font sizes
    ax.set_xlabel('Exploration Steps', fontsize=18, fontweight='medium')
    ax.set_ylabel('Intrinsic Reward', fontsize=18, fontweight='medium')

    # Legend outside the plot area - optimized positioning
    ax.legend(fontsize=15, bbox_to_anchor=(0.5, 1.02), loc='lower center',
             ncol=3, frameon=True, fancybox=True, framealpha=0.9,
             columnspacing=1.0, handlelength=1.8, handletextpad=0.5)

    ax.grid(True, alpha=0.3, linewidth=0.5)
    ax.tick_params(axis='both', which='major', labelsize=15)

    # Adjust layout to accommodate legend
    plt.tight_layout()
    plt.subplots_adjust(top=0.88)  # More conservative than your original 0.85
    plt.savefig(f'exploration_methods_v1_{num_runs}runs.pdf',
                dpi=300, bbox_inches='tight', pad_inches=0.1)
    plt.show()

    # # Create combined plot
    # plt.figure(figsize=(20, 12))

    # # Plot all methods with different line styles for deterministic vs stochastic
    # for method in ['mse', 'ama', 'uncertainty']:
    #     # Deterministic
    #     mean_det = stats[method]['det']['mean'][start_idx:]
    #     std_det = stats[method]['det']['std'][start_idx:]
    #     plt.plot(steps, mean_det, label=f'{labels[method]} Deterministic',
    #             color=colors[method], linestyle='-', linewidth=2)
    #     plt.fill_between(steps, mean_det - std_det, mean_det + std_det,
    #                     color=colors[method], alpha=0.15)

    #     # Stochastic
    #     mean_stoch = stats[method]['stoch']['mean'][start_idx:]
    #     std_stoch = stats[method]['stoch']['std'][start_idx:]
    #     plt.plot(steps, mean_stoch, label=f'{labels[method]} Stochastic',
    #             color=colors[method], linestyle='--', linewidth=2)
    #     plt.fill_between(steps, mean_stoch - std_stoch, mean_stoch + std_stoch,
    #                     color=colors[method], alpha=0.15)

    # plt.xlabel('Exploration Steps', fontsize=47, fontweight='medium')
    # plt.ylabel('Intrinsic Reward', fontsize=47, fontweight='medium')

    # # Place legend outside the figure at the top
    # plt.legend(fontsize=40, bbox_to_anchor=(0.5, 1.04), loc='lower center', ncol=3)

    # plt.grid(True, alpha=0.3)
    # plt.xticks(fontsize=44, fontweight='medium')
    # plt.yticks(fontsize=44, fontweight='medium')

    # # Adjust layout to prevent legend cutoff
    # plt.tight_layout()
    # plt.subplots_adjust(top=0.85)

    # plt.savefig(f'exploration_methods_combined_{num_runs}runs.pdf', dpi=1000, bbox_inches='tight')
    # plt.show()

    # Save detailed results
    detailed_results = {
        'num_runs': num_runs,
        'steps_plotted': steps,
        'statistics': stats,
        'raw_results': all_results,
        'parameters': {
            'training_steps': training_steps,
            'checkpoint_loss': checkpoint_loss,
            'mse_lr': mse_lr,
            'ama_lr': ama_lr,
            'uncertainty_mse_lr': uncertainty_mse_lr,
            'uncertainty_lr': uncertainty_lr,
            'lambda_param': lambda_param,
            'eta_param': eta_param,
            'max_buffer_size': max_buffer_size,
            'uncertainty_update_freq': uncertainty_update_freq,
            'uncertainty_batch_size': uncertainty_batch_size
        }
    }

    np.save(f'exploration_methods_comparison_{num_runs}runs_results.npy', detailed_results)

    print("\n" + "="*60)
    print("MULTI-RUN EXPERIMENT COMPLETED!")
    print("="*60)
    print(f"Results saved to: exploration_methods_comparison_{num_runs}runs_results.npy")
    print(f"Plots saved to: exploration_methods_comparison_{num_runs}runs.png and exploration_methods_combined_{num_runs}runs.png")

    # Print summary statistics
    print(f"\nSUMMARY STATISTICS (Final Values, {num_runs} runs):")
    print("-" * 50)
    for method in ['mse', 'ama', 'uncertainty']:
        print(f"\n{labels[method]}:")
        for condition, condition_name in [('det', 'Deterministic'), ('stoch', 'Stochastic')]:
            final_mean = stats[method][condition]['mean'][-1]
            final_std = stats[method][condition]['std'][-1]
            print(f"  {condition_name}: {final_mean:.4f} ± {final_std:.4f}")

    return detailed_results

if __name__ == "__main__":
    # Set parameters
    num_runs = 5
    training_steps = 600
    checkpoint_loss = 10

    # Learning rates
    mse_lr = 0.001
    ama_lr = 0.001
    uncertainty_mse_lr = 0.001
    uncertainty_lr = 0.001

    # Model-specific parameters
    lambda_param = 1.0
    eta_param = 1.0

    # Uncertainty predictor specific parameters
    max_buffer_size = 100
    uncertainty_update_freq = 5
    uncertainty_batch_size = 32

    print(f"Starting comprehensive exploration methods comparison with {num_runs} runs...")

    results = run_multiple_experiments_and_compare(
        num_runs=num_runs,
        training_steps=training_steps,
        checkpoint_loss=checkpoint_loss,
        mse_lr=mse_lr,
        ama_lr=ama_lr,
        uncertainty_mse_lr=uncertainty_mse_lr,
        uncertainty_lr=uncertainty_lr,
        lambda_param=lambda_param,
        eta_param=eta_param,
        max_buffer_size=max_buffer_size,
        uncertainty_update_freq=uncertainty_update_freq,
        uncertainty_batch_size=uncertainty_batch_size
    )
# Out:
# /Users/yingtexu/Codebase/ChallengingRL/LPM_exploration/.venv/lib/python3.11/site-packages/mnist/loader.py:179: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.return_type is 'lists':
# /Users/yingtexu/Codebase/ChallengingRL/LPM_exploration/.venv/lib/python3.11/site-packages/mnist/loader.py:181: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif self.return_type is 'numpy':
# /Users/yingtexu/Codebase/ChallengingRL/LPM_exploration/.venv/lib/python3.11/site-packages/mnist/loader.py:187: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.return_type is 'lists':
# /Users/yingtexu/Codebase/ChallengingRL/LPM_exploration/.venv/lib/python3.11/site-packages/mnist/loader.py:189: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif self.return_type is 'numpy':
# /Users/yingtexu/Codebase/ChallengingRL/LPM_exploration/.venv/lib/python3.11/site-packages/mnist/loader.py:243: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if type(batch) is not list or len(batch) is not 2:
# Using device: cpu
# MNIST data loaded successfully
# Starting comprehensive exploration methods comparison with 5 runs...
# ============================================================
# RUNNING COMPARATIVE EXPLORATION EXPERIMENTS (5 runs each)
# ============================================================
#
# --- Run 1/5 ---
# Running MSE Baseline (Run 1)...
# Training MSEExperiment (seed=42):   0%|          | 0/600 [00:00<?, ?it/s]
# Training MSEExperiment (seed=42):   2%|▏         | 10/600 [00:00<00:06, 96.63it/s]
# Training MSEExperiment (seed=42):   4%|▎         | 22/600 [00:00<00:05, 108.34it/s]
# Training MSEExperiment (seed=42):   6%|▌         | 34/600 [00:00<00:05, 112.78it/s]
# Training MSEExperiment (seed=42):   8%|▊         | 46/600 [00:00<00:04, 114.65it/s]
# Training MSEExperiment (seed=42):  10%|▉         | 58/600 [00:00<00:04, 116.31it/s]
# Training MSEExperiment (seed=42):  12%|█▏        | 70/600 [00:00<00:04, 116.54it/s]
# Training MSEExperiment (seed=42):  14%|█▎        | 82/600 [00:00<00:04, 116.59it/s]
# Training MSEExperiment (seed=42):  16%|█▌        | 95/600 [00:00<00:04, 117.84it/s]
# Training MSEExperiment (seed=42):  18%|█▊        | 107/600 [00:00<00:04, 117.87it/s]
# Training MSEExperiment (seed=42):  20%|█▉        | 119/600 [00:01<00:04, 117.86it/s]
# Training MSEExperiment (seed=42):  22%|██▏       | 131/600 [00:01<00:04, 116.20it/s]
# Training MSEExperiment (seed=42):  24%|██▍       | 143/600 [00:01<00:03, 115.86it/s]
# Training MSEExperiment (seed=42):  26%|██▌       | 155/600 [00:01<00:03, 116.77it/s]
# Training MSEExperiment (seed=42):  28%|██▊       | 167/600 [00:01<00:03, 117.00it/s]
# Training MSEExperiment (seed=42):  30%|██▉       | 179/600 [00:01<00:03, 117.16it/s]
# Training MSEExperiment (seed=42):  32%|███▏      | 191/600 [00:01<00:03, 117.73it/s]
# Training MSEExperiment (seed=42):  34%|███▍      | 203/600 [00:01<00:03, 117.42it/s]
# Training MSEExperiment (seed=42):  36%|███▌      | 215/600 [00:01<00:03, 117.96it/s]
# Training MSEExperiment (seed=42):  38%|███▊      | 227/600 [00:01<00:03, 118.02it/s]
# Training MSEExperiment (seed=42):  40%|████      | 240/600 [00:02<00:03, 118.66it/s]
# Training MSEExperiment (seed=42):  42%|████▏     | 252/600 [00:02<00:02, 118.75it/s]
# Training MSEExperiment (seed=42):  44%|████▍     | 265/600 [00:02<00:02, 119.07it/s]
# Training MSEExperiment (seed=42):  46%|████▌     | 277/600 [00:02<00:02, 118.90it/s]
# Training MSEExperiment (seed=42):  48%|████▊     | 289/600 [00:02<00:02, 118.85it/s]
# Training MSEExperiment (seed=42):  50%|█████     | 301/600 [00:02<00:02, 118.61it/s]
# Training MSEExperiment (seed=42):  52%|█████▏    | 313/600 [00:02<00:02, 118.68it/s]
# Training MSEExperiment (seed=42):  54%|█████▍    | 325/600 [00:02<00:02, 118.96it/s]
# Training MSEExperiment (seed=42):  56%|█████▌    | 337/600 [00:02<00:02, 118.98it/s]
# Training MSEExperiment (seed=42):  58%|█████▊    | 349/600 [00:02<00:02, 119.14it/s]
# Training MSEExperiment (seed=42):  60%|██████    | 362/600 [00:03<00:01, 119.59it/s]
# Training MSEExperiment (seed=42):  62%|██████▏   | 374/600 [00:03<00:01, 118.80it/s]
# Training MSEExperiment (seed=42):  64%|██████▍   | 386/600 [00:03<00:01, 119.01it/s]
# Training MSEExperiment (seed=42):  66%|██████▋   | 398/600 [00:03<00:01, 118.62it/s]
# Training MSEExperiment (seed=42):  68%|██████▊   | 410/600 [00:03<00:01, 118.64it/s]
# Training MSEExperiment (seed=42):  70%|███████   | 422/600 [00:03<00:01, 117.83it/s]
# Training MSEExperiment (seed=42):  72%|███████▏  | 434/600 [00:03<00:01, 117.02it/s]
# Training MSEExperiment (seed=42):  74%|███████▍  | 446/600 [00:03<00:01, 116.77it/s]
# Training MSEExperiment (seed=42):  76%|███████▋  | 458/600 [00:03<00:01, 117.15it/s]
# Training MSEExperiment (seed=42):  78%|███████▊  | 470/600 [00:04<00:01, 114.99it/s]
# Training MSEExperiment (seed=42):  80%|████████  | 482/600 [00:04<00:01, 113.89it/s]
# Training MSEExperiment (seed=42):  82%|████████▏ | 494/600 [00:04<00:00, 113.31it/s]
# Training MSEExperiment (seed=42):  84%|████████▍ | 506/600 [00:04<00:00, 112.67it/s]
# Training MSEExperiment (seed=42):  86%|████████▋ | 518/600 [00:04<00:00, 112.53it/s]
# Training MSEExperiment (seed=42):  88%|████████▊ | 530/600 [00:04<00:00, 111.80it/s]
# Training MSEExperiment (seed=42):  90%|█████████ | 542/600 [00:04<00:00, 111.51it/s]
# Training MSEExperiment (seed=42):  92%|█████████▏| 554/600 [00:04<00:00, 111.90it/s]
# Training MSEExperiment (seed=42):  94%|█████████▍| 566/600 [00:04<00:00, 111.55it/s]
# Training MSEExperiment (seed=42):  96%|█████████▋| 578/600 [00:04<00:00, 112.35it/s]
# Training MSEExperiment (seed=42):  98%|█████████▊| 590/600 [00:05<00:00, 112.57it/s]
# Training MSEExperiment (seed=42): 100%|██████████| 600/600 [00:05<00:00, 116.02it/s]
# Running AMA (Run 1)...
# Training AMAExperiment (seed=42):   0%|          | 0/600 [00:00<?, ?it/s]
# Training AMAExperiment (seed=42):   2%|▏         | 9/600 [00:00<00:07, 82.73it/s]
# Training AMAExperiment (seed=42):   3%|▎         | 18/600 [00:00<00:06, 84.13it/s]
# Training AMAExperiment (seed=42):   4%|▍         | 27/600 [00:00<00:06, 85.20it/s]
# Training AMAExperiment (seed=42):   6%|▌         | 36/600 [00:00<00:06, 86.30it/s]
# Training AMAExperiment (seed=42):   8%|▊         | 45/600 [00:00<00:06, 86.46it/s]
# Training AMAExperiment (seed=42):   9%|▉         | 54/600 [00:00<00:06, 87.10it/s]
# Training AMAExperiment (seed=42):  10%|█         | 63/600 [00:00<00:06, 86.87it/s]
# Training AMAExperiment (seed=42):  12%|█▏        | 72/600 [00:00<00:06, 87.81it/s]
# Training AMAExperiment (seed=42):  14%|█▎        | 81/600 [00:00<00:05, 88.41it/s]
# Training AMAExperiment (seed=42):  15%|█▌        | 91/600 [00:01<00:05, 89.05it/s]
# Training AMAExperiment (seed=42):  17%|█▋        | 101/600 [00:01<00:05, 89.65it/s]
# Training AMAExperiment (seed=42):  18%|█▊        | 111/600 [00:01<00:05, 89.90it/s]
# Training AMAExperiment (seed=42):  20%|██        | 120/600 [00:01<00:05, 89.69it/s]
# Training AMAExperiment (seed=42):  22%|██▏       | 130/600 [00:01<00:05, 89.96it/s]
# Training AMAExperiment (seed=42):  23%|██▎       | 140/600 [00:01<00:05, 90.36it/s]
# Training AMAExperiment (seed=42):  25%|██▌       | 150/600 [00:01<00:04, 90.44it/s]
# Training AMAExperiment (seed=42):  27%|██▋       | 160/600 [00:01<00:04, 90.54it/s]
# Training AMAExperiment (seed=42):  28%|██▊       | 170/600 [00:01<00:04, 90.50it/s]
# Training AMAExperiment (seed=42):  30%|███       | 180/600 [00:02<00:04, 89.75it/s]
# Training AMAExperiment (seed=42):  32%|███▏      | 190/600 [00:02<00:04, 90.15it/s]
# Training AMAExperiment (seed=42):  33%|███▎      | 200/600 [00:02<00:04, 89.47it/s]
# Training AMAExperiment (seed=42):  35%|███▌      | 210/600 [00:02<00:04, 89.85it/s]
# Training AMAExperiment (seed=42):  36%|███▋      | 219/600 [00:02<00:04, 89.69it/s]
# Training AMAExperiment (seed=42):  38%|███▊      | 229/600 [00:02<00:04, 90.11it/s]
# Training AMAExperiment (seed=42):  40%|███▉      | 239/600 [00:02<00:03, 90.67it/s]
# Training AMAExperiment (seed=42):  42%|████▏     | 249/600 [00:02<00:03, 90.40it/s]
# Training AMAExperiment (seed=42):  43%|████▎     | 259/600 [00:02<00:03, 90.79it/s]
# Training AMAExperiment (seed=42):  45%|████▍     | 269/600 [00:03<00:03, 91.07it/s]
# Training AMAExperiment (seed=42):  46%|████▋     | 279/600 [00:03<00:03, 90.73it/s]
# Training AMAExperiment (seed=42):  48%|████▊     | 289/600 [00:03<00:03, 90.91it/s]
# Training AMAExperiment (seed=42):  50%|████▉     | 299/600 [00:03<00:03, 91.09it/s]
# Training AMAExperiment (seed=42):  52%|█████▏    | 309/600 [00:03<00:03, 90.45it/s]
# Training AMAExperiment (seed=42):  53%|█████▎    | 319/600 [00:03<00:03, 90.32it/s]
# Training AMAExperiment (seed=42):  55%|█████▍    | 329/600 [00:03<00:03, 90.11it/s]
# Training AMAExperiment (seed=42):  56%|█████▋    | 339/600 [00:03<00:02, 89.90it/s]
# Training AMAExperiment (seed=42):  58%|█████▊    | 349/600 [00:03<00:02, 90.38it/s]
# Training AMAExperiment (seed=42):  60%|█████▉    | 359/600 [00:04<00:02, 90.54it/s]
# Training AMAExperiment (seed=42):  62%|██████▏   | 369/600 [00:04<00:02, 90.75it/s]
# Training AMAExperiment (seed=42):  63%|██████▎   | 379/600 [00:04<00:02, 90.81it/s]
# Training AMAExperiment (seed=42):  65%|██████▍   | 389/600 [00:04<00:02, 89.67it/s]
# Training AMAExperiment (seed=42):  66%|██████▋   | 398/600 [00:04<00:02, 89.65it/s]
# Training AMAExperiment (seed=42):  68%|██████▊   | 408/600 [00:04<00:02, 90.17it/s]
# Training AMAExperiment (seed=42):  70%|██████▉   | 418/600 [00:04<00:02, 90.47it/s]
# Training AMAExperiment (seed=42):  71%|███████▏  | 428/600 [00:04<00:01, 90.56it/s]
# Training AMAExperiment (seed=42):  73%|███████▎  | 438/600 [00:04<00:01, 90.59it/s]
# Training AMAExperiment (seed=42):  75%|███████▍  | 448/600 [00:04<00:01, 90.18it/s]
# Training AMAExperiment (seed=42):  76%|███████▋  | 458/600 [00:05<00:01, 90.40it/s]
# Training AMAExperiment (seed=42):  78%|███████▊  | 468/600 [00:05<00:01, 90.75it/s]
# Training AMAExperiment (seed=42):  80%|███████▉  | 478/600 [00:05<00:01, 90.74it/s]
# Training AMAExperiment (seed=42):  81%|████████▏ | 488/600 [00:05<00:01, 89.97it/s]
# Training AMAExperiment (seed=42):  83%|████████▎ | 497/600 [00:05<00:01, 89.91it/s]
# Training AMAExperiment (seed=42):  84%|████████▍ | 506/600 [00:05<00:01, 89.72it/s]
# Training AMAExperiment (seed=42):  86%|████████▌ | 515/600 [00:05<00:00, 89.76it/s]
# Training AMAExperiment (seed=42):  88%|████████▊ | 525/600 [00:05<00:00, 89.95it/s]
# Training AMAExperiment (seed=42):  89%|████████▉ | 535/600 [00:05<00:00, 90.11it/s]
# Training AMAExperiment (seed=42):  91%|█████████ | 545/600 [00:06<00:00, 90.08it/s]
# Training AMAExperiment (seed=42):  92%|█████████▎| 555/600 [00:06<00:00, 90.08it/s]
# Training AMAExperiment (seed=42):  94%|█████████▍| 565/600 [00:06<00:00, 90.81it/s]
# Training AMAExperiment (seed=42):  96%|█████████▌| 575/600 [00:06<00:00, 90.94it/s]
# Training AMAExperiment (seed=42):  98%|█████████▊| 585/600 [00:06<00:00, 88.68it/s]
# Training AMAExperiment (seed=42):  99%|█████████▉| 595/600 [00:06<00:00, 89.35it/s]
# Training AMAExperiment (seed=42): 100%|██████████| 600/600 [00:06<00:00, 89.75it/s]
# Running Uncertainty Predictor (Run 1)...
# Training UncertaintyPredictorExperiment (seed=42):   0%|          | 0/600 [00:00<?, ?it/s]
# Training UncertaintyPredictorExperiment (seed=42):   2%|▏         | 11/600 [00:00<00:05, 103.00it/s]
# Training UncertaintyPredictorExperiment (seed=42):   4%|▎         | 22/600 [00:00<00:05, 102.45it/s]
# Training UncertaintyPredictorExperiment (seed=42):   6%|▌         | 33/600 [00:00<00:05, 103.65it/s]
# Training UncertaintyPredictorExperiment (seed=42):   7%|▋         | 44/600 [00:00<00:05, 104.70it/s]
# Training UncertaintyPredictorExperiment (seed=42):   9%|▉         | 55/600 [00:00<00:05, 104.77it/s]
# Training UncertaintyPredictorExperiment (seed=42):  11%|█         | 66/600 [00:00<00:05, 104.53it/s]
# Training UncertaintyPredictorExperiment (seed=42):  13%|█▎        | 77/600 [00:00<00:05, 103.87it/s]
# Training UncertaintyPredictorExperiment (seed=42):  15%|█▍        | 88/600 [00:00<00:04, 104.27it/s]
# Training UncertaintyPredictorExperiment (seed=42):  16%|█▋        | 99/600 [00:00<00:04, 104.30it/s]
# Training UncertaintyPredictorExperiment (seed=42):  18%|█▊        | 110/600 [00:01<00:04, 103.74it/s]
# Training UncertaintyPredictorExperiment (seed=42):  20%|██        | 121/600 [00:01<00:04, 104.12it/s]
# Training UncertaintyPredictorExperiment (seed=42):  22%|██▏       | 132/600 [00:01<00:04, 103.22it/s]
# Training UncertaintyPredictorExperiment (seed=42):  24%|██▍       | 143/600 [00:01<00:04, 103.88it/s]
# Training UncertaintyPredictorExperiment (seed=42):  26%|██▌       | 154/600 [00:01<00:04, 103.52it/s]
# Training UncertaintyPredictorExperiment (seed=42):  28%|██▊       | 165/600 [00:01<00:04, 103.62it/s]
# Training UncertaintyPredictorExperiment (seed=42):  29%|██▉       | 176/600 [00:01<00:04, 103.85it/s]
# Training UncertaintyPredictorExperiment (seed=42):  31%|███       | 187/600 [00:01<00:04, 103.16it/s]
# Training UncertaintyPredictorExperiment (seed=42):  33%|███▎      | 198/600 [00:01<00:03, 102.19it/s]
# Training UncertaintyPredictorExperiment (seed=42):  35%|███▍      | 209/600 [00:02<00:03, 102.30it/s]
# Training UncertaintyPredictorExperiment (seed=42):  37%|███▋      | 220/600 [00:02<00:03, 102.93it/s]
# Training UncertaintyPredictorExperiment (seed=42):  38%|███▊      | 231/600 [00:02<00:03, 103.60it/s]
# Training UncertaintyPredictorExperiment (seed=42):  40%|████      | 242/600 [00:02<00:03, 104.13it/s]
# Training UncertaintyPredictorExperiment (seed=42):  42%|████▏     | 253/600 [00:02<00:03, 104.83it/s]
# Training UncertaintyPredictorExperiment (seed=42):  44%|████▍     | 264/600 [00:02<00:03, 104.59it/s]
# Training UncertaintyPredictorExperiment (seed=42):  46%|████▌     | 275/600 [00:02<00:03, 104.17it/s]
# Training UncertaintyPredictorExperiment (seed=42):  48%|████▊     | 286/600 [00:02<00:03, 103.55it/s]
# Training UncertaintyPredictorExperiment (seed=42):  50%|████▉     | 297/600 [00:02<00:02, 103.83it/s]
# Training UncertaintyPredictorExperiment (seed=42):  51%|█████▏    | 308/600 [00:02<00:02, 104.51it/s]
# Training UncertaintyPredictorExperiment (seed=42):  53%|█████▎    | 319/600 [00:03<00:02, 104.28it/s]
# Training UncertaintyPredictorExperiment (seed=42):  55%|█████▌    | 330/600 [00:03<00:02, 101.52it/s]
# Training UncertaintyPredictorExperiment (seed=42):  57%|█████▋    | 341/600 [00:03<00:02, 101.56it/s]
# Training UncertaintyPredictorExperiment (seed=42):  59%|█████▊    | 352/600 [00:03<00:02, 101.54it/s]
# Training UncertaintyPredictorExperiment (seed=42):  60%|██████    | 363/600 [00:03<00:02, 101.62it/s]
# Training UncertaintyPredictorExperiment (seed=42):  62%|██████▏   | 374/600 [00:03<00:02, 102.20it/s]
# Training UncertaintyPredictorExperiment (seed=42):  64%|██████▍   | 385/600 [00:03<00:02, 101.76it/s]
# Training UncertaintyPredictorExperiment (seed=42):  66%|██████▌   | 396/600 [00:03<00:02, 101.65it/s]
# Training UncertaintyPredictorExperiment (seed=42):  68%|██████▊   | 407/600 [00:03<00:01, 101.87it/s]
# Training UncertaintyPredictorExperiment (seed=42):  70%|██████▉   | 418/600 [00:04<00:01, 101.46it/s]
# Training UncertaintyPredictorExperiment (seed=42):  72%|███████▏  | 429/600 [00:04<00:01, 101.48it/s]
# Training UncertaintyPredictorExperiment (seed=42):  73%|███████▎  | 440/600 [00:04<00:01, 102.50it/s]
# Training UncertaintyPredictorExperiment (seed=42):  75%|███████▌  | 451/600 [00:04<00:01, 103.03it/s]
# Training UncertaintyPredictorExperiment (seed=42):  77%|███████▋  | 462/600 [00:04<00:01, 103.66it/s]
# Training UncertaintyPredictorExperiment (seed=42):  79%|███████▉  | 473/600 [00:04<00:01, 104.34it/s]
# Training UncertaintyPredictorExperiment (seed=42):  81%|████████  | 484/600 [00:04<00:01, 104.00it/s]
# Training UncertaintyPredictorExperiment (seed=42):  82%|████████▎ | 495/600 [00:04<00:01, 103.27it/s]
# Training UncertaintyPredictorExperiment (seed=42):  84%|████████▍ | 506/600 [00:04<00:00, 102.33it/s]
# Training UncertaintyPredictorExperiment (seed=42):  86%|████████▌ | 517/600 [00:05<00:00, 102.77it/s]
# Training UncertaintyPredictorExperiment (seed=42):  88%|████████▊ | 528/600 [00:05<00:00, 102.14it/s]
# Training UncertaintyPredictorExperiment (seed=42):  90%|████████▉ | 539/600 [00:05<00:00, 102.69it/s]
# Training UncertaintyPredictorExperiment (seed=42):  92%|█████████▏| 550/600 [00:05<00:00, 103.60it/s]
# Training UncertaintyPredictorExperiment (seed=42):  94%|█████████▎| 561/600 [00:05<00:00, 103.69it/s]
# Training UncertaintyPredictorExperiment (seed=42):  95%|█████████▌| 572/600 [00:05<00:00, 103.58it/s]
# Training UncertaintyPredictorExperiment (seed=42):  97%|█████████▋| 583/600 [00:05<00:00, 103.56it/s]
# Training UncertaintyPredictorExperiment (seed=42):  99%|█████████▉| 594/600 [00:05<00:00, 103.21it/s]
# Training UncertaintyPredictorExperiment (seed=42): 100%|██████████| 600/600 [00:05<00:00, 103.18it/s]
# --- Run 2/5 ---
# Running MSE Baseline (Run 2)...
# Training MSEExperiment (seed=1042):   0%|          | 0/600 [00:00<?, ?it/s]
# Training MSEExperiment (seed=1042):   2%|▏         | 12/600 [00:00<00:05, 113.37it/s]
# Training MSEExperiment (seed=1042):   4%|▍         | 24/600 [00:00<00:05, 114.29it/s]
# Training MSEExperiment (seed=1042):   6%|▌         | 36/600 [00:00<00:04, 114.06it/s]
# Training MSEExperiment (seed=1042):   8%|▊         | 48/600 [00:00<00:04, 112.88it/s]
# Training MSEExperiment (seed=1042):  10%|█         | 60/600 [00:00<00:04, 112.46it/s]
# Training MSEExperiment (seed=1042):  12%|█▏        | 72/600 [00:00<00:04, 111.14it/s]
# Training MSEExperiment (seed=1042):  14%|█▍        | 84/600 [00:00<00:04, 111.53it/s]
# Training MSEExperiment (seed=1042):  16%|█▌        | 96/600 [00:00<00:04, 111.42it/s]
# Training MSEExperiment (seed=1042):  18%|█▊        | 108/600 [00:00<00:04, 110.92it/s]
# Training MSEExperiment (seed=1042):  20%|██        | 120/600 [00:01<00:04, 111.95it/s]
# Training MSEExperiment (seed=1042):  22%|██▏       | 132/600 [00:01<00:04, 112.02it/s]
# Training MSEExperiment (seed=1042):  24%|██▍       | 144/600 [00:01<00:04, 112.22it/s]
# Training MSEExperiment (seed=1042):  26%|██▌       | 156/600 [00:01<00:03, 112.41it/s]
# Training MSEExperiment (seed=1042):  28%|██▊       | 168/600 [00:01<00:03, 113.16it/s]
# Training MSEExperiment (seed=1042):  30%|███       | 180/600 [00:01<00:03, 113.98it/s]
# Training MSEExperiment (seed=1042):  32%|███▏      | 192/600 [00:01<00:03, 114.31it/s]
# Training MSEExperiment (seed=1042):  34%|███▍      | 204/600 [00:01<00:03, 114.43it/s]
# Training MSEExperiment (seed=1042):  36%|███▌      | 216/600 [00:01<00:03, 114.06it/s]
# Training MSEExperiment (seed=1042):  38%|███▊      | 228/600 [00:02<00:03, 114.22it/s]
# Training MSEExperiment (seed=1042):  40%|████      | 240/600 [00:02<00:03, 114.13it/s]
# Training MSEExperiment (seed=1042):  42%|████▏     | 252/600 [00:02<00:03, 113.90it/s]
# Training MSEExperiment (seed=1042):  44%|████▍     | 264/600 [00:02<00:02, 113.99it/s]
# Training MSEExperiment (seed=1042):  46%|████▌     | 276/600 [00:02<00:02, 113.96it/s]
# Training MSEExperiment (seed=1042):  48%|████▊     | 288/600 [00:02<00:02, 113.71it/s]
# Training MSEExperiment (seed=1042):  50%|█████     | 301/600 [00:02<00:02, 115.62it/s]
# Training MSEExperiment (seed=1042):  52%|█████▏    | 313/600 [00:02<00:02, 116.45it/s]
# Training MSEExperiment (seed=1042):  54%|█████▍    | 325/600 [00:02<00:02, 116.95it/s]
# Training MSEExperiment (seed=1042):  56%|█████▌    | 337/600 [00:02<00:02, 116.46it/s]
# Training MSEExperiment (seed=1042):  58%|█████▊    | 349/600 [00:03<00:02, 116.84it/s]
# Training MSEExperiment (seed=1042):  60%|██████    | 361/600 [00:03<00:02, 116.27it/s]
# Training MSEExperiment (seed=1042):  62%|██████▏   | 373/600 [00:03<00:01, 115.57it/s]
# Training MSEExperiment (seed=1042):  64%|██████▍   | 385/600 [00:03<00:01, 116.00it/s]
# Training MSEExperiment (seed=1042):  66%|██████▌   | 397/600 [00:03<00:01, 115.75it/s]
# Training MSEExperiment (seed=1042):  68%|██████▊   | 409/600 [00:03<00:01, 116.44it/s]
# Training MSEExperiment (seed=1042):  70%|███████   | 421/600 [00:03<00:01, 116.59it/s]
# Training MSEExperiment (seed=1042):  72%|███████▏  | 433/600 [00:03<00:01, 116.66it/s]
# Training MSEExperiment (seed=1042):  74%|███████▍  | 445/600 [00:03<00:01, 116.84it/s]
# Training MSEExperiment (seed=1042):  76%|███████▌  | 457/600 [00:03<00:01, 116.64it/s]
# Training MSEExperiment (seed=1042):  78%|███████▊  | 469/600 [00:04<00:01, 116.92it/s]
# Training MSEExperiment (seed=1042):  80%|████████  | 481/600 [00:04<00:01, 116.46it/s]
# Training MSEExperiment (seed=1042):  82%|████████▏ | 493/600 [00:04<00:00, 116.66it/s]
# Training MSEExperiment (seed=1042):  84%|████████▍ | 505/600 [00:04<00:00, 116.10it/s]
# Training MSEExperiment (seed=1042):  86%|████████▌ | 517/600 [00:04<00:00, 116.08it/s]
# Training MSEExperiment (seed=1042):  88%|████████▊ | 529/600 [00:04<00:00, 114.86it/s]
# Training MSEExperiment (seed=1042):  90%|█████████ | 541/600 [00:04<00:00, 115.34it/s]
# Training MSEExperiment (seed=1042):  92%|█████████▏| 553/600 [00:04<00:00, 115.99it/s]
# Training MSEExperiment (seed=1042):  94%|█████████▍| 565/600 [00:04<00:00, 116.00it/s]
# Training MSEExperiment (seed=1042):  96%|█████████▌| 577/600 [00:05<00:00, 116.12it/s]
# Training MSEExperiment (seed=1042):  98%|█████████▊| 589/600 [00:05<00:00, 115.90it/s]
# Training MSEExperiment (seed=1042): 100%|██████████| 600/600 [00:05<00:00, 114.78it/s]
# Running AMA (Run 2)...
# Training AMAExperiment (seed=1042):   0%|          | 0/600 [00:00<?, ?it/s]
# Training AMAExperiment (seed=1042):   2%|▏         | 9/600 [00:00<00:06, 86.94it/s]
# Training AMAExperiment (seed=1042):   3%|▎         | 18/600 [00:00<00:06, 88.33it/s]
# Training AMAExperiment (seed=1042):   4%|▍         | 27/600 [00:00<00:06, 88.19it/s]
# Training AMAExperiment (seed=1042):   6%|▌         | 37/600 [00:00<00:06, 89.21it/s]
# Training AMAExperiment (seed=1042):   8%|▊         | 46/600 [00:00<00:06, 89.31it/s]
# Training AMAExperiment (seed=1042):   9%|▉         | 55/600 [00:00<00:06, 89.32it/s]
# Training AMAExperiment (seed=1042):  11%|█         | 64/600 [00:00<00:06, 88.57it/s]
# Training AMAExperiment (seed=1042):  12%|█▏        | 73/600 [00:00<00:05, 88.79it/s]
# Training AMAExperiment (seed=1042):  14%|█▎        | 82/600 [00:00<00:05, 89.15it/s]
# Training AMAExperiment (seed=1042):  15%|█▌        | 91/600 [00:01<00:05, 89.09it/s]
# Training AMAExperiment (seed=1042):  17%|█▋        | 100/600 [00:01<00:05, 89.28it/s]
# Training AMAExperiment (seed=1042):  18%|█▊        | 110/600 [00:01<00:05, 89.52it/s]
# Training AMAExperiment (seed=1042):  20%|██        | 120/600 [00:01<00:05, 90.01it/s]
# Training AMAExperiment (seed=1042):  22%|██▏       | 129/600 [00:01<00:05, 88.84it/s]
# Training AMAExperiment (seed=1042):  23%|██▎       | 139/600 [00:01<00:05, 89.46it/s]
# Training AMAExperiment (seed=1042):  25%|██▍       | 148/600 [00:01<00:05, 89.58it/s]
# Training AMAExperiment (seed=1042):  26%|██▋       | 158/600 [00:01<00:04, 89.63it/s]
# Training AMAExperiment (seed=1042):  28%|██▊       | 168/600 [00:01<00:04, 89.83it/s]
# Training AMAExperiment (seed=1042):  30%|██▉       | 177/600 [00:01<00:04, 89.49it/s]
# Training AMAExperiment (seed=1042):  31%|███       | 186/600 [00:02<00:04, 89.49it/s]
# Training AMAExperiment (seed=1042):  32%|███▎      | 195/600 [00:02<00:04, 89.55it/s]
# Training AMAExperiment (seed=1042):  34%|███▍      | 204/600 [00:02<00:04, 89.62it/s]
# Training AMAExperiment (seed=1042):  36%|███▌      | 214/600 [00:02<00:04, 89.90it/s]
# Training AMAExperiment (seed=1042):  37%|███▋      | 223/600 [00:02<00:04, 89.75it/s]
# Training AMAExperiment (seed=1042):  39%|███▊      | 232/600 [00:02<00:04, 89.69it/s]
# Training AMAExperiment (seed=1042):  40%|████      | 242/600 [00:02<00:03, 89.80it/s]
# Training AMAExperiment (seed=1042):  42%|████▏     | 251/600 [00:02<00:03, 89.49it/s]
# Training AMAExperiment (seed=1042):  44%|████▎     | 261/600 [00:02<00:03, 90.01it/s]
# Training AMAExperiment (seed=1042):  45%|████▌     | 270/600 [00:03<00:03, 89.45it/s]
# Training AMAExperiment (seed=1042):  46%|████▋     | 279/600 [00:03<00:03, 88.73it/s]
# Training AMAExperiment (seed=1042):  48%|████▊     | 288/600 [00:03<00:03, 88.20it/s]
# Training AMAExperiment (seed=1042):  50%|████▉     | 297/600 [00:03<00:03, 88.17it/s]
# Training AMAExperiment (seed=1042):  51%|█████     | 306/600 [00:03<00:03, 88.16it/s]
# Training AMAExperiment (seed=1042):  52%|█████▎    | 315/600 [00:03<00:03, 86.92it/s]
# Training AMAExperiment (seed=1042):  54%|█████▍    | 324/600 [00:03<00:03, 84.69it/s]
# Training AMAExperiment (seed=1042):  56%|█████▌    | 333/600 [00:03<00:03, 84.84it/s]
# Training AMAExperiment (seed=1042):  57%|█████▋    | 342/600 [00:03<00:03, 85.97it/s]
# Training AMAExperiment (seed=1042):  58%|█████▊    | 351/600 [00:03<00:02, 86.97it/s]
# Training AMAExperiment (seed=1042):  60%|██████    | 360/600 [00:04<00:02, 87.10it/s]
# Training AMAExperiment (seed=1042):  62%|██████▏   | 369/600 [00:04<00:02, 87.14it/s]
# Training AMAExperiment (seed=1042):  63%|██████▎   | 379/600 [00:04<00:02, 89.20it/s]
# Training AMAExperiment (seed=1042):  65%|██████▍   | 389/600 [00:04<00:02, 89.34it/s]
# Training AMAExperiment (seed=1042):  66%|██████▋   | 398/600 [00:04<00:02, 88.96it/s]
# Training AMAExperiment (seed=1042):  68%|██████▊   | 408/600 [00:04<00:02, 89.52it/s]
# Training AMAExperiment (seed=1042):  70%|██████▉   | 417/600 [00:04<00:02, 87.26it/s]
# Training AMAExperiment (seed=1042):  71%|███████   | 426/600 [00:04<00:02, 83.96it/s]
# Training AMAExperiment (seed=1042):  72%|███████▎  | 435/600 [00:04<00:01, 82.76it/s]
# Training AMAExperiment (seed=1042):  74%|███████▍  | 444/600 [00:05<00:01, 81.69it/s]
# Training AMAExperiment (seed=1042):  76%|███████▌  | 453/600 [00:05<00:01, 81.61it/s]
# Training AMAExperiment (seed=1042):  77%|███████▋  | 462/600 [00:05<00:01, 82.29it/s]
# Training AMAExperiment (seed=1042):  78%|███████▊  | 471/600 [00:05<00:01, 83.38it/s]
# Training AMAExperiment (seed=1042):  80%|████████  | 480/600 [00:05<00:01, 85.08it/s]
# Training AMAExperiment (seed=1042):  82%|████████▏ | 489/600 [00:05<00:01, 85.69it/s]
# Training AMAExperiment (seed=1042):  83%|████████▎ | 498/600 [00:05<00:01, 84.69it/s]
# Training AMAExperiment (seed=1042):  84%|████████▍ | 507/600 [00:05<00:01, 84.77it/s]
# Training AMAExperiment (seed=1042):  86%|████████▌ | 516/600 [00:05<00:00, 85.55it/s]
# Training AMAExperiment (seed=1042):  88%|████████▊ | 525/600 [00:05<00:00, 86.66it/s]
# Training AMAExperiment (seed=1042):  89%|████████▉ | 535/600 [00:06<00:00, 87.75it/s]
# Training AMAExperiment (seed=1042):  91%|█████████ | 545/600 [00:06<00:00, 88.76it/s]
# Training AMAExperiment (seed=1042):  92%|█████████▎| 555/600 [00:06<00:00, 89.74it/s]
# Training AMAExperiment (seed=1042):  94%|█████████▍| 565/600 [00:06<00:00, 90.74it/s]
# Training AMAExperiment (seed=1042):  96%|█████████▌| 575/600 [00:06<00:00, 91.43it/s]
# Training AMAExperiment (seed=1042):  98%|█████████▊| 585/600 [00:06<00:00, 92.05it/s]
# Training AMAExperiment (seed=1042):  99%|█████████▉| 595/600 [00:06<00:00, 91.71it/s]
# Training AMAExperiment (seed=1042): 100%|██████████| 600/600 [00:06<00:00, 88.10it/s]
# Running Uncertainty Predictor (Run 2)...
# Training UncertaintyPredictorExperiment (seed=1042):   0%|          | 0/600 [00:00<?, ?it/s]
# Training UncertaintyPredictorExperiment (seed=1042):   2%|▏         | 11/600 [00:00<00:05, 106.81it/s]
# Training UncertaintyPredictorExperiment (seed=1042):   4%|▎         | 22/600 [00:00<00:05, 102.63it/s]
# Training UncertaintyPredictorExperiment (seed=1042):   6%|▌         | 33/600 [00:00<00:05, 103.34it/s]
# Training UncertaintyPredictorExperiment (seed=1042):   7%|▋         | 44/600 [00:00<00:05, 104.74it/s]
# Training UncertaintyPredictorExperiment (seed=1042):   9%|▉         | 55/600 [00:00<00:05, 103.69it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  11%|█         | 66/600 [00:00<00:05, 104.55it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  13%|█▎        | 77/600 [00:00<00:05, 104.31it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  15%|█▍        | 88/600 [00:00<00:04, 103.91it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  16%|█▋        | 99/600 [00:00<00:04, 102.43it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  18%|█▊        | 110/600 [00:01<00:04, 101.91it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  20%|██        | 121/600 [00:01<00:04, 101.47it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  22%|██▏       | 132/600 [00:01<00:04, 100.26it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  24%|██▍       | 143/600 [00:01<00:04, 99.46it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  26%|██▌       | 153/600 [00:01<00:04, 96.99it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  27%|██▋       | 163/600 [00:01<00:04, 96.91it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  29%|██▉       | 173/600 [00:01<00:04, 97.76it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  31%|███       | 184/600 [00:01<00:04, 98.54it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  32%|███▏      | 194/600 [00:01<00:04, 98.84it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  34%|███▍      | 204/600 [00:02<00:04, 96.01it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  36%|███▌      | 214/600 [00:02<00:04, 96.40it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  37%|███▋      | 224/600 [00:02<00:03, 95.72it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  39%|███▉      | 234/600 [00:02<00:03, 95.95it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  41%|████      | 244/600 [00:02<00:03, 95.83it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  42%|████▏     | 254/600 [00:02<00:03, 95.35it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  44%|████▍     | 264/600 [00:02<00:03, 95.96it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  46%|████▌     | 274/600 [00:02<00:03, 95.77it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  47%|████▋     | 284/600 [00:02<00:03, 95.27it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  49%|████▉     | 294/600 [00:02<00:03, 94.83it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  51%|█████     | 304/600 [00:03<00:03, 94.36it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  52%|█████▏    | 314/600 [00:03<00:03, 93.45it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  54%|█████▍    | 324/600 [00:03<00:02, 92.22it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  56%|█████▌    | 334/600 [00:03<00:02, 93.46it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  57%|█████▋    | 344/600 [00:03<00:02, 94.36it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  59%|█████▉    | 354/600 [00:03<00:02, 94.17it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  61%|██████    | 364/600 [00:03<00:02, 93.78it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  62%|██████▏   | 374/600 [00:03<00:02, 93.34it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  64%|██████▍   | 384/600 [00:03<00:02, 93.17it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  66%|██████▌   | 394/600 [00:04<00:02, 93.47it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  67%|██████▋   | 404/600 [00:04<00:02, 94.15it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  69%|██████▉   | 414/600 [00:04<00:01, 95.00it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  71%|███████   | 425/600 [00:04<00:01, 96.71it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  73%|███████▎  | 436/600 [00:04<00:01, 98.02it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  74%|███████▍  | 447/600 [00:04<00:01, 99.77it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  76%|███████▋  | 458/600 [00:04<00:01, 100.01it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  78%|███████▊  | 469/600 [00:04<00:01, 100.52it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  80%|████████  | 480/600 [00:04<00:01, 100.28it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  82%|████████▏ | 491/600 [00:05<00:01, 100.60it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  84%|████████▎ | 502/600 [00:05<00:00, 100.73it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  86%|████████▌ | 513/600 [00:05<00:00, 99.92it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  87%|████████▋ | 523/600 [00:05<00:00, 99.44it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  89%|████████▉ | 534/600 [00:05<00:00, 100.81it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  91%|█████████ | 545/600 [00:05<00:00, 101.75it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  93%|█████████▎| 556/600 [00:05<00:00, 102.66it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  94%|█████████▍| 567/600 [00:05<00:00, 102.92it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  96%|█████████▋| 578/600 [00:05<00:00, 101.99it/s]
# Training UncertaintyPredictorExperiment (seed=1042):  98%|█████████▊| 589/600 [00:05<00:00, 102.74it/s]
# Training UncertaintyPredictorExperiment (seed=1042): 100%|██████████| 600/600 [00:06<00:00, 103.14it/s]
# Training UncertaintyPredictorExperiment (seed=1042): 100%|██████████| 600/600 [00:06<00:00, 98.59it/s]
# --- Run 3/5 ---
# Running MSE Baseline (Run 3)...
# Training MSEExperiment (seed=2042):   0%|          | 0/600 [00:00<?, ?it/s]
# Training MSEExperiment (seed=2042):   2%|▏         | 12/600 [00:00<00:05, 114.65it/s]
# Training MSEExperiment (seed=2042):   4%|▍         | 24/600 [00:00<00:05, 114.76it/s]
# Training MSEExperiment (seed=2042):   6%|▌         | 36/600 [00:00<00:04, 113.61it/s]
# Training MSEExperiment (seed=2042):   8%|▊         | 48/600 [00:00<00:04, 112.37it/s]
# Training MSEExperiment (seed=2042):  10%|█         | 60/600 [00:00<00:04, 112.70it/s]
# Training MSEExperiment (seed=2042):  12%|█▏        | 72/600 [00:00<00:04, 112.26it/s]
# Training MSEExperiment (seed=2042):  14%|█▍        | 84/600 [00:00<00:04, 112.16it/s]
# Training MSEExperiment (seed=2042):  16%|█▌        | 96/600 [00:00<00:04, 111.70it/s]
# Training MSEExperiment (seed=2042):  18%|█▊        | 108/600 [00:00<00:04, 112.46it/s]
# Training MSEExperiment (seed=2042):  20%|██        | 120/600 [00:01<00:04, 110.13it/s]
# Training MSEExperiment (seed=2042):  22%|██▏       | 132/600 [00:01<00:04, 109.17it/s]
# Training MSEExperiment (seed=2042):  24%|██▍       | 143/600 [00:01<00:04, 108.56it/s]
# Training MSEExperiment (seed=2042):  26%|██▌       | 155/600 [00:01<00:04, 109.93it/s]
# Training MSEExperiment (seed=2042):  28%|██▊       | 167/600 [00:01<00:03, 111.05it/s]
# Training MSEExperiment (seed=2042):  30%|██▉       | 179/600 [00:01<00:03, 111.62it/s]
# Training MSEExperiment (seed=2042):  32%|███▏      | 191/600 [00:01<00:03, 111.44it/s]
# Training MSEExperiment (seed=2042):  34%|███▍      | 203/600 [00:01<00:03, 111.45it/s]
# Training MSEExperiment (seed=2042):  36%|███▌      | 215/600 [00:01<00:03, 111.83it/s]
# Training MSEExperiment (seed=2042):  38%|███▊      | 227/600 [00:02<00:03, 111.21it/s]
# Training MSEExperiment (seed=2042):  40%|███▉      | 239/600 [00:02<00:03, 111.31it/s]
# Training MSEExperiment (seed=2042):  42%|████▏     | 251/600 [00:02<00:03, 111.43it/s]
# Training MSEExperiment (seed=2042):  44%|████▍     | 263/600 [00:02<00:03, 112.02it/s]
# Training MSEExperiment (seed=2042):  46%|████▌     | 275/600 [00:02<00:02, 112.99it/s]
# Training MSEExperiment (seed=2042):  48%|████▊     | 287/600 [00:02<00:02, 113.02it/s]
# Training MSEExperiment (seed=2042):  50%|████▉     | 299/600 [00:02<00:02, 112.32it/s]
# Training MSEExperiment (seed=2042):  52%|█████▏    | 311/600 [00:02<00:02, 111.26it/s]
# Training MSEExperiment (seed=2042):  54%|█████▍    | 323/600 [00:02<00:02, 111.76it/s]
# Training MSEExperiment (seed=2042):  56%|█████▌    | 335/600 [00:02<00:02, 112.53it/s]
# Training MSEExperiment (seed=2042):  58%|█████▊    | 347/600 [00:03<00:02, 112.70it/s]
# Training MSEExperiment (seed=2042):  60%|█████▉    | 359/600 [00:03<00:02, 112.43it/s]
# Training MSEExperiment (seed=2042):  62%|██████▏   | 371/600 [00:03<00:02, 112.79it/s]
# Training MSEExperiment (seed=2042):  64%|██████▍   | 383/600 [00:03<00:01, 112.12it/s]
# Training MSEExperiment (seed=2042):  66%|██████▌   | 395/600 [00:03<00:01, 113.53it/s]
# Training MSEExperiment (seed=2042):  68%|██████▊   | 407/600 [00:03<00:01, 115.14it/s]
# Training MSEExperiment (seed=2042):  70%|██████▉   | 419/600 [00:03<00:01, 115.15it/s]
# Training MSEExperiment (seed=2042):  72%|███████▏  | 431/600 [00:03<00:01, 114.23it/s]
# Training MSEExperiment (seed=2042):  74%|███████▍  | 443/600 [00:03<00:01, 114.84it/s]
# Training MSEExperiment (seed=2042):  76%|███████▌  | 455/600 [00:04<00:01, 113.99it/s]
# Training MSEExperiment (seed=2042):  78%|███████▊  | 467/600 [00:04<00:01, 114.81it/s]
# Training MSEExperiment (seed=2042):  80%|███████▉  | 479/600 [00:04<00:01, 114.21it/s]
# Training MSEExperiment (seed=2042):  82%|████████▏ | 491/600 [00:04<00:00, 115.21it/s]
# Training MSEExperiment (seed=2042):  84%|████████▍ | 503/600 [00:04<00:00, 115.96it/s]
# Training MSEExperiment (seed=2042):  86%|████████▌ | 515/600 [00:04<00:00, 116.07it/s]
# Training MSEExperiment (seed=2042):  88%|████████▊ | 527/600 [00:04<00:00, 116.70it/s]
# Training MSEExperiment (seed=2042):  90%|████████▉ | 539/600 [00:04<00:00, 116.98it/s]
# Training MSEExperiment (seed=2042):  92%|█████████▏| 551/600 [00:04<00:00, 116.54it/s]
# Training MSEExperiment (seed=2042):  94%|█████████▍| 563/600 [00:04<00:00, 116.76it/s]
# Training MSEExperiment (seed=2042):  96%|█████████▌| 575/600 [00:05<00:00, 116.72it/s]
# Training MSEExperiment (seed=2042):  98%|█████████▊| 587/600 [00:05<00:00, 117.52it/s]
# Training MSEExperiment (seed=2042): 100%|█████████▉| 599/600 [00:05<00:00, 117.48it/s]
# Training MSEExperiment (seed=2042): 100%|██████████| 600/600 [00:05<00:00, 113.40it/s]
# Running AMA (Run 3)...
# Training AMAExperiment (seed=2042):   0%|          | 0/600 [00:00<?, ?it/s]
# Training AMAExperiment (seed=2042):   2%|▏         | 9/600 [00:00<00:06, 88.85it/s]
# Training AMAExperiment (seed=2042):   3%|▎         | 18/600 [00:00<00:06, 87.35it/s]
# Training AMAExperiment (seed=2042):   5%|▍         | 28/600 [00:00<00:06, 89.62it/s]
# Training AMAExperiment (seed=2042):   6%|▋         | 38/600 [00:00<00:06, 90.00it/s]
# Training AMAExperiment (seed=2042):   8%|▊         | 47/600 [00:00<00:06, 89.89it/s]
# Training AMAExperiment (seed=2042):  10%|▉         | 57/600 [00:00<00:06, 90.00it/s]
# Training AMAExperiment (seed=2042):  11%|█         | 66/600 [00:00<00:05, 89.82it/s]
# Training AMAExperiment (seed=2042):  12%|█▎        | 75/600 [00:00<00:05, 89.66it/s]
# Training AMAExperiment (seed=2042):  14%|█▍        | 84/600 [00:00<00:05, 89.69it/s]
# Training AMAExperiment (seed=2042):  16%|█▌        | 93/600 [00:01<00:05, 89.04it/s]
# Training AMAExperiment (seed=2042):  17%|█▋        | 102/600 [00:01<00:05, 88.86it/s]
# Training AMAExperiment (seed=2042):  18%|█▊        | 111/600 [00:01<00:05, 88.71it/s]
# Training AMAExperiment (seed=2042):  20%|██        | 120/600 [00:01<00:05, 88.77it/s]
# Training AMAExperiment (seed=2042):  22%|██▏       | 129/600 [00:01<00:05, 88.78it/s]
# Training AMAExperiment (seed=2042):  23%|██▎       | 138/600 [00:01<00:05, 88.29it/s]
# Training AMAExperiment (seed=2042):  24%|██▍       | 147/600 [00:01<00:05, 88.28it/s]
# Training AMAExperiment (seed=2042):  26%|██▌       | 156/600 [00:01<00:05, 88.38it/s]
# Training AMAExperiment (seed=2042):  28%|██▊       | 165/600 [00:01<00:04, 88.59it/s]
# Training AMAExperiment (seed=2042):  29%|██▉       | 175/600 [00:01<00:04, 89.01it/s]
# Training AMAExperiment (seed=2042):  31%|███       | 184/600 [00:02<00:04, 88.82it/s]
# Training AMAExperiment (seed=2042):  32%|███▏      | 193/600 [00:02<00:04, 88.69it/s]
# Training AMAExperiment (seed=2042):  34%|███▎      | 202/600 [00:02<00:04, 87.71it/s]
# Training AMAExperiment (seed=2042):  35%|███▌      | 211/600 [00:02<00:04, 87.65it/s]
# Training AMAExperiment (seed=2042):  37%|███▋      | 220/600 [00:02<00:04, 87.53it/s]
# Training AMAExperiment (seed=2042):  38%|███▊      | 229/600 [00:02<00:04, 87.00it/s]
# Training AMAExperiment (seed=2042):  40%|███▉      | 238/600 [00:02<00:04, 87.43it/s]
# Training AMAExperiment (seed=2042):  41%|████▏     | 248/600 [00:02<00:03, 88.53it/s]
# Training AMAExperiment (seed=2042):  43%|████▎     | 257/600 [00:02<00:03, 88.91it/s]
# Training AMAExperiment (seed=2042):  44%|████▍     | 266/600 [00:02<00:03, 89.00it/s]
# Training AMAExperiment (seed=2042):  46%|████▌     | 275/600 [00:03<00:03, 89.04it/s]
# Training AMAExperiment (seed=2042):  47%|████▋     | 284/600 [00:03<00:03, 89.07it/s]
# Training AMAExperiment (seed=2042):  49%|████▉     | 293/600 [00:03<00:03, 88.78it/s]
# Training AMAExperiment (seed=2042):  50%|█████     | 302/600 [00:03<00:03, 88.45it/s]
# Training AMAExperiment (seed=2042):  52%|█████▏    | 311/600 [00:03<00:03, 88.00it/s]
# Training AMAExperiment (seed=2042):  53%|█████▎    | 320/600 [00:03<00:03, 87.13it/s]
# Training AMAExperiment (seed=2042):  55%|█████▌    | 330/600 [00:03<00:03, 88.23it/s]
# Training AMAExperiment (seed=2042):  57%|█████▋    | 340/600 [00:03<00:02, 88.79it/s]
# Training AMAExperiment (seed=2042):  58%|█████▊    | 349/600 [00:03<00:02, 88.22it/s]
# Training AMAExperiment (seed=2042):  60%|█████▉    | 358/600 [00:04<00:02, 87.93it/s]
# Training AMAExperiment (seed=2042):  61%|██████    | 367/600 [00:04<00:02, 88.15it/s]
# Training AMAExperiment (seed=2042):  63%|██████▎   | 376/600 [00:04<00:02, 88.24it/s]
# Training AMAExperiment (seed=2042):  64%|██████▍   | 386/600 [00:04<00:02, 88.77it/s]
# Training AMAExperiment (seed=2042):  66%|██████▌   | 395/600 [00:04<00:02, 87.68it/s]
# Training AMAExperiment (seed=2042):  67%|██████▋   | 404/600 [00:04<00:02, 87.38it/s]
# Training AMAExperiment (seed=2042):  69%|██████▉   | 413/600 [00:04<00:02, 87.70it/s]
# Training AMAExperiment (seed=2042):  70%|███████   | 422/600 [00:04<00:02, 87.27it/s]
# Training AMAExperiment (seed=2042):  72%|███████▏  | 431/600 [00:04<00:01, 87.57it/s]
# Training AMAExperiment (seed=2042):  73%|███████▎  | 440/600 [00:04<00:01, 86.56it/s]
# Training AMAExperiment (seed=2042):  75%|███████▍  | 449/600 [00:05<00:01, 86.08it/s]
# Training AMAExperiment (seed=2042):  76%|███████▋  | 458/600 [00:05<00:01, 85.38it/s]
# Training AMAExperiment (seed=2042):  78%|███████▊  | 467/600 [00:05<00:01, 85.26it/s]
# Training AMAExperiment (seed=2042):  79%|███████▉  | 476/600 [00:05<00:01, 85.35it/s]
# Training AMAExperiment (seed=2042):  81%|████████  | 485/600 [00:05<00:01, 84.70it/s]
# Training AMAExperiment (seed=2042):  82%|████████▏ | 494/600 [00:05<00:01, 85.23it/s]
# Training AMAExperiment (seed=2042):  84%|████████▍ | 503/600 [00:05<00:01, 85.56it/s]
# Training AMAExperiment (seed=2042):  85%|████████▌ | 512/600 [00:05<00:01, 85.62it/s]
# Training AMAExperiment (seed=2042):  87%|████████▋ | 521/600 [00:05<00:00, 86.06it/s]
# Training AMAExperiment (seed=2042):  88%|████████▊ | 530/600 [00:06<00:00, 86.72it/s]
# Training AMAExperiment (seed=2042):  90%|████████▉ | 539/600 [00:06<00:00, 86.84it/s]
# Training AMAExperiment (seed=2042):  91%|█████████▏| 548/600 [00:06<00:00, 87.06it/s]
# Training AMAExperiment (seed=2042):  93%|█████████▎| 557/600 [00:06<00:00, 86.92it/s]
# Training AMAExperiment (seed=2042):  94%|█████████▍| 566/600 [00:06<00:00, 87.18it/s]
# Training AMAExperiment (seed=2042):  96%|█████████▌| 575/600 [00:06<00:00, 85.87it/s]
# Training AMAExperiment (seed=2042):  97%|█████████▋| 584/600 [00:06<00:00, 85.92it/s]
# Training AMAExperiment (seed=2042):  99%|█████████▉| 593/600 [00:06<00:00, 86.35it/s]
# Training AMAExperiment (seed=2042): 100%|██████████| 600/600 [00:06<00:00, 87.70it/s]
# Running Uncertainty Predictor (Run 3)...
# Training UncertaintyPredictorExperiment (seed=2042):   0%|          | 0/600 [00:00<?, ?it/s]
# Training UncertaintyPredictorExperiment (seed=2042):   2%|▏         | 11/600 [00:00<00:05, 102.05it/s]
# Training UncertaintyPredictorExperiment (seed=2042):   4%|▎         | 22/600 [00:00<00:05, 103.30it/s]
# Training UncertaintyPredictorExperiment (seed=2042):   6%|▌         | 33/600 [00:00<00:05, 104.30it/s]
# Training UncertaintyPredictorExperiment (seed=2042):   7%|▋         | 44/600 [00:00<00:05, 104.36it/s]
# Training UncertaintyPredictorExperiment (seed=2042):   9%|▉         | 55/600 [00:00<00:05, 102.83it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  11%|█         | 66/600 [00:00<00:05, 102.95it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  13%|█▎        | 77/600 [00:00<00:05, 102.65it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  15%|█▍        | 88/600 [00:00<00:04, 103.44it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  16%|█▋        | 99/600 [00:00<00:04, 103.47it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  18%|█▊        | 110/600 [00:01<00:04, 102.01it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  20%|██        | 121/600 [00:01<00:04, 102.97it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  22%|██▏       | 132/600 [00:01<00:04, 103.66it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  24%|██▍       | 143/600 [00:01<00:04, 103.86it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  26%|██▌       | 154/600 [00:01<00:04, 103.06it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  28%|██▊       | 165/600 [00:01<00:04, 102.82it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  29%|██▉       | 176/600 [00:01<00:04, 102.65it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  31%|███       | 187/600 [00:01<00:04, 101.83it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  33%|███▎      | 198/600 [00:01<00:03, 102.10it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  35%|███▍      | 209/600 [00:02<00:03, 102.47it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  37%|███▋      | 220/600 [00:02<00:03, 101.89it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  38%|███▊      | 231/600 [00:02<00:03, 101.81it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  40%|████      | 242/600 [00:02<00:03, 102.46it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  42%|████▏     | 253/600 [00:02<00:03, 102.31it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  44%|████▍     | 264/600 [00:02<00:03, 101.95it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  46%|████▌     | 275/600 [00:02<00:03, 100.73it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  48%|████▊     | 286/600 [00:02<00:03, 101.14it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  50%|████▉     | 297/600 [00:02<00:03, 100.31it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  51%|█████▏    | 308/600 [00:03<00:02, 101.03it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  53%|█████▎    | 319/600 [00:03<00:02, 101.45it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  55%|█████▌    | 330/600 [00:03<00:02, 101.41it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  57%|█████▋    | 341/600 [00:03<00:02, 102.30it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  59%|█████▊    | 352/600 [00:03<00:02, 101.49it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  60%|██████    | 363/600 [00:03<00:02, 101.95it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  62%|██████▏   | 374/600 [00:03<00:02, 101.71it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  64%|██████▍   | 385/600 [00:03<00:02, 102.09it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  66%|██████▌   | 396/600 [00:03<00:01, 102.71it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  68%|██████▊   | 407/600 [00:03<00:01, 97.60it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  70%|██████▉   | 417/600 [00:04<00:01, 98.21it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  71%|███████▏  | 428/600 [00:04<00:01, 99.91it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  73%|███████▎  | 439/600 [00:04<00:01, 101.08it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  75%|███████▌  | 450/600 [00:04<00:01, 100.29it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  77%|███████▋  | 461/600 [00:04<00:01, 101.51it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  79%|███████▊  | 472/600 [00:04<00:01, 102.18it/s]
# Training UncertaintyPredictorExperiment (seed=2042):  80%|████████  | 483/600 [00:04<00:01, 102.54it/s]
# ...
# Training MSEExperiment (seed=4042):  22%|██▏       | 132/600 [00:01<00:04, 115.37it/s]
# Training MSEExperiment (seed=4042):  24%|██▍       | 144/600 [00:01<00:03, 114.22it/s]
# Training MSEExperiment (seed=4042):  26%|██▌       | 156/600 [00:01<00:03, 114.76it/s]
# Training MSEExperiment (seed=4042):  28%|██▊       | 169/600 [00:01<00:03, 116.42it/s]
# Training MSEExperiment (seed=4042):  30%|███       | 181/600 [00:01<00:03, 115.89it/s]
# Training MSEExperiment (seed=4042):  32%|███▏      | 193/600 [00:01<00:03, 115.18it/s]
# Training MSEExperiment (seed=4042):  34%|███▍      | 205/600 [00:01<00:03, 114.77it/s]
# Training MSEExperiment (seed=4042):  36%|███▌      | 217/600 [00:01<00:03, 114.20it/s]
# Training MSEExperiment (seed=4042):  38%|███▊      | 229/600 [00:01<00:03, 114.08it/s]
# Training MSEExperiment (seed=4042):  40%|████      | 241/600 [00:02<00:03, 113.56it/s]
# Training MSEExperiment (seed=4042):  42%|████▏     | 253/600 [00:02<00:03, 114.25it/s]
# Training MSEExperiment (seed=4042):  44%|████▍     | 265/600 [00:02<00:02, 114.03it/s]
# Training MSEExperiment (seed=4042):  46%|████▌     | 277/600 [00:02<00:02, 114.40it/s]
# Training MSEExperiment (seed=4042):  48%|████▊     | 289/600 [00:02<00:02, 114.24it/s]
# Training MSEExperiment (seed=4042):  50%|█████     | 301/600 [00:02<00:02, 113.34it/s]
# Training MSEExperiment (seed=4042):  52%|█████▏    | 313/600 [00:02<00:02, 114.08it/s]
# Training MSEExperiment (seed=4042):  54%|█████▍    | 325/600 [00:02<00:02, 113.94it/s]
# Training MSEExperiment (seed=4042):  56%|█████▌    | 337/600 [00:02<00:02, 114.88it/s]
# Training MSEExperiment (seed=4042):  58%|█████▊    | 349/600 [00:03<00:02, 114.61it/s]
# Training MSEExperiment (seed=4042):  60%|██████    | 361/600 [00:03<00:02, 114.69it/s]
# Training MSEExperiment (seed=4042):  62%|██████▏   | 373/600 [00:03<00:01, 114.77it/s]
# Training MSEExperiment (seed=4042):  64%|██████▍   | 385/600 [00:03<00:01, 114.32it/s]
# Training MSEExperiment (seed=4042):  66%|██████▌   | 397/600 [00:03<00:01, 115.41it/s]
# Training MSEExperiment (seed=4042):  68%|██████▊   | 409/600 [00:03<00:01, 116.49it/s]
# Training MSEExperiment (seed=4042):  70%|███████   | 421/600 [00:03<00:01, 116.65it/s]
# Training MSEExperiment (seed=4042):  72%|███████▏  | 433/600 [00:03<00:01, 117.29it/s]
# Training MSEExperiment (seed=4042):  74%|███████▍  | 445/600 [00:03<00:01, 117.15it/s]
# Training MSEExperiment (seed=4042):  76%|███████▌  | 457/600 [00:03<00:01, 117.51it/s]
# Training MSEExperiment (seed=4042):  78%|███████▊  | 469/600 [00:04<00:01, 117.72it/s]
# Training MSEExperiment (seed=4042):  80%|████████  | 481/600 [00:04<00:01, 117.37it/s]
# Training MSEExperiment (seed=4042):  82%|████████▏ | 493/600 [00:04<00:00, 117.43it/s]
# Training MSEExperiment (seed=4042):  84%|████████▍ | 505/600 [00:04<00:00, 117.71it/s]
# Training MSEExperiment (seed=4042):  86%|████████▌ | 517/600 [00:04<00:00, 117.43it/s]
# Training MSEExperiment (seed=4042):  88%|████████▊ | 529/600 [00:04<00:00, 117.37it/s]
# Training MSEExperiment (seed=4042):  90%|█████████ | 541/600 [00:04<00:00, 117.75it/s]
# Training MSEExperiment (seed=4042):  92%|█████████▏| 553/600 [00:04<00:00, 117.61it/s]
# Training MSEExperiment (seed=4042):  94%|█████████▍| 565/600 [00:04<00:00, 117.78it/s]
# Training MSEExperiment (seed=4042):  96%|█████████▌| 577/600 [00:04<00:00, 118.16it/s]
# Training MSEExperiment (seed=4042):  98%|█████████▊| 589/600 [00:05<00:00, 117.72it/s]
# Training MSEExperiment (seed=4042): 100%|██████████| 600/600 [00:05<00:00, 115.78it/s]
# Running AMA (Run 5)...
# Training AMAExperiment (seed=4042):   0%|          | 0/600 [00:00<?, ?it/s]
# Training AMAExperiment (seed=4042):   2%|▏         | 10/600 [00:00<00:06, 90.28it/s]
# Training AMAExperiment (seed=4042):   3%|▎         | 20/600 [00:00<00:06, 91.72it/s]
# Training AMAExperiment (seed=4042):   5%|▌         | 30/600 [00:00<00:06, 88.41it/s]
# Training AMAExperiment (seed=4042):   7%|▋         | 40/600 [00:00<00:06, 88.96it/s]
# Training AMAExperiment (seed=4042):   8%|▊         | 49/600 [00:00<00:06, 89.17it/s]
# Training AMAExperiment (seed=4042):  10%|▉         | 58/600 [00:00<00:06, 89.32it/s]
# Training AMAExperiment (seed=4042):  11%|█         | 67/600 [00:00<00:05, 89.53it/s]
# Training AMAExperiment (seed=4042):  13%|█▎        | 76/600 [00:00<00:05, 89.19it/s]
# Training AMAExperiment (seed=4042):  14%|█▍        | 85/600 [00:00<00:05, 88.37it/s]
# Training AMAExperiment (seed=4042):  16%|█▌        | 94/600 [00:01<00:05, 88.37it/s]
# Training AMAExperiment (seed=4042):  17%|█▋        | 103/600 [00:01<00:05, 87.99it/s]
# Training AMAExperiment (seed=4042):  19%|█▊        | 112/600 [00:01<00:05, 86.83it/s]
# Training AMAExperiment (seed=4042):  20%|██        | 121/600 [00:01<00:05, 87.36it/s]
# Training AMAExperiment (seed=4042):  22%|██▏       | 130/600 [00:01<00:05, 87.66it/s]
# Training AMAExperiment (seed=4042):  23%|██▎       | 139/600 [00:01<00:05, 87.49it/s]
# Training AMAExperiment (seed=4042):  25%|██▍       | 148/600 [00:01<00:05, 86.79it/s]
# Training AMAExperiment (seed=4042):  26%|██▌       | 157/600 [00:01<00:05, 87.27it/s]
# Training AMAExperiment (seed=4042):  28%|██▊       | 166/600 [00:01<00:04, 87.04it/s]
# Training AMAExperiment (seed=4042):  29%|██▉       | 175/600 [00:01<00:04, 87.38it/s]
# Training AMAExperiment (seed=4042):  31%|███       | 184/600 [00:02<00:04, 87.63it/s]
# Training AMAExperiment (seed=4042):  32%|███▏      | 193/600 [00:02<00:04, 87.91it/s]
# Training AMAExperiment (seed=4042):  34%|███▎      | 202/600 [00:02<00:04, 88.28it/s]
# Training AMAExperiment (seed=4042):  35%|███▌      | 211/600 [00:02<00:04, 87.03it/s]
# Training AMAExperiment (seed=4042):  37%|███▋      | 220/600 [00:02<00:04, 87.39it/s]
# Training AMAExperiment (seed=4042):  38%|███▊      | 229/600 [00:02<00:04, 87.83it/s]
# Training AMAExperiment (seed=4042):  40%|███▉      | 238/600 [00:02<00:04, 88.28it/s]
# Training AMAExperiment (seed=4042):  41%|████      | 247/600 [00:02<00:03, 88.56it/s]
# Training AMAExperiment (seed=4042):  43%|████▎     | 256/600 [00:02<00:03, 88.65it/s]
# Training AMAExperiment (seed=4042):  44%|████▍     | 265/600 [00:03<00:03, 89.00it/s]
# Training AMAExperiment (seed=4042):  46%|████▌     | 274/600 [00:03<00:03, 88.34it/s]
# Training AMAExperiment (seed=4042):  47%|████▋     | 283/600 [00:03<00:03, 88.44it/s]
# Training AMAExperiment (seed=4042):  49%|████▊     | 292/600 [00:03<00:03, 88.79it/s]
# Training AMAExperiment (seed=4042):  50%|█████     | 301/600 [00:03<00:03, 88.27it/s]
# Training AMAExperiment (seed=4042):  52%|█████▏    | 310/600 [00:03<00:03, 87.59it/s]
# Training AMAExperiment (seed=4042):  53%|█████▎    | 319/600 [00:03<00:03, 87.29it/s]
# Training AMAExperiment (seed=4042):  55%|█████▍    | 328/600 [00:03<00:03, 87.24it/s]
# Training AMAExperiment (seed=4042):  56%|█████▌    | 337/600 [00:03<00:03, 86.70it/s]
# Training AMAExperiment (seed=4042):  58%|█████▊    | 346/600 [00:03<00:02, 87.06it/s]
# Training AMAExperiment (seed=4042):  59%|█████▉    | 355/600 [00:04<00:02, 87.77it/s]
# Training AMAExperiment (seed=4042):  61%|██████    | 364/600 [00:04<00:02, 88.27it/s]
# Training AMAExperiment (seed=4042):  62%|██████▏   | 374/600 [00:04<00:02, 89.21it/s]
# Training AMAExperiment (seed=4042):  64%|██████▍   | 383/600 [00:04<00:02, 89.36it/s]
# Training AMAExperiment (seed=4042):  66%|██████▌   | 393/600 [00:04<00:02, 89.47it/s]
# Training AMAExperiment (seed=4042):  67%|██████▋   | 402/600 [00:04<00:02, 87.92it/s]
# Training AMAExperiment (seed=4042):  68%|██████▊   | 411/600 [00:04<00:02, 87.30it/s]
# Training AMAExperiment (seed=4042):  70%|███████   | 420/600 [00:04<00:02, 87.63it/s]
# Training AMAExperiment (seed=4042):  72%|███████▏  | 429/600 [00:04<00:01, 88.13it/s]
# Training AMAExperiment (seed=4042):  73%|███████▎  | 438/600 [00:04<00:01, 88.37it/s]
# Training AMAExperiment (seed=4042):  74%|███████▍  | 447/600 [00:05<00:01, 88.64it/s]
# Training AMAExperiment (seed=4042):  76%|███████▌  | 456/600 [00:05<00:01, 88.72it/s]
# Training AMAExperiment (seed=4042):  78%|███████▊  | 465/600 [00:05<00:01, 88.89it/s]
# Training AMAExperiment (seed=4042):  79%|███████▉  | 474/600 [00:05<00:01, 89.21it/s]
# Training AMAExperiment (seed=4042):  80%|████████  | 483/600 [00:05<00:01, 89.21it/s]
# Training AMAExperiment (seed=4042):  82%|████████▏ | 493/600 [00:05<00:01, 89.44it/s]
# Training AMAExperiment (seed=4042):  84%|████████▎ | 502/600 [00:05<00:01, 88.82it/s]
# Training AMAExperiment (seed=4042):  85%|████████▌ | 511/600 [00:05<00:00, 89.12it/s]
# Training AMAExperiment (seed=4042):  87%|████████▋ | 520/600 [00:05<00:00, 89.27it/s]
# Training AMAExperiment (seed=4042):  88%|████████▊ | 529/600 [00:05<00:00, 89.45it/s]
# Training AMAExperiment (seed=4042):  90%|████████▉ | 538/600 [00:06<00:00, 89.25it/s]
# Training AMAExperiment (seed=4042):  91%|█████████ | 547/600 [00:06<00:00, 89.11it/s]
# Training AMAExperiment (seed=4042):  93%|█████████▎| 557/600 [00:06<00:00, 89.47it/s]
# Training AMAExperiment (seed=4042):  94%|█████████▍| 567/600 [00:06<00:00, 89.72it/s]
# Training AMAExperiment (seed=4042):  96%|█████████▌| 577/600 [00:06<00:00, 90.04it/s]
# Training AMAExperiment (seed=4042):  98%|█████████▊| 587/600 [00:06<00:00, 88.48it/s]
# Training AMAExperiment (seed=4042):  99%|█████████▉| 596/600 [00:06<00:00, 88.65it/s]
# Training AMAExperiment (seed=4042): 100%|██████████| 600/600 [00:06<00:00, 88.40it/s]
# Running Uncertainty Predictor (Run 5)...
# Training UncertaintyPredictorExperiment (seed=4042):   0%|          | 0/600 [00:00<?, ?it/s]
# Training UncertaintyPredictorExperiment (seed=4042):   2%|▏         | 11/600 [00:00<00:05, 102.91it/s]
# Training UncertaintyPredictorExperiment (seed=4042):   4%|▎         | 22/600 [00:00<00:05, 101.99it/s]
# Training UncertaintyPredictorExperiment (seed=4042):   6%|▌         | 33/600 [00:00<00:05, 101.77it/s]
# Training UncertaintyPredictorExperiment (seed=4042):   7%|▋         | 44/600 [00:00<00:05, 101.59it/s]
# Training UncertaintyPredictorExperiment (seed=4042):   9%|▉         | 55/600 [00:00<00:05, 100.41it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  11%|█         | 66/600 [00:00<00:05, 99.94it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  13%|█▎        | 76/600 [00:00<00:05, 99.31it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  14%|█▍        | 86/600 [00:00<00:05, 98.98it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  16%|█▌        | 97/600 [00:00<00:05, 99.47it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  18%|█▊        | 107/600 [00:01<00:04, 98.82it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  20%|█▉        | 117/600 [00:01<00:04, 97.73it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  21%|██        | 127/600 [00:01<00:04, 98.16it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  23%|██▎       | 138/600 [00:01<00:04, 98.99it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  25%|██▍       | 149/600 [00:01<00:04, 99.74it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  27%|██▋       | 160/600 [00:01<00:04, 99.56it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  28%|██▊       | 171/600 [00:01<00:04, 99.78it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  30%|███       | 181/600 [00:01<00:04, 98.79it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  32%|███▏      | 191/600 [00:01<00:04, 98.47it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  34%|███▎      | 201/600 [00:02<00:04, 97.87it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  35%|███▌      | 211/600 [00:02<00:03, 98.39it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  37%|███▋      | 221/600 [00:02<00:03, 97.42it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  39%|███▊      | 232/600 [00:02<00:03, 98.79it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  40%|████      | 243/600 [00:02<00:03, 100.73it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  42%|████▏     | 254/600 [00:02<00:03, 100.94it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  44%|████▍     | 265/600 [00:02<00:03, 100.78it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  46%|████▌     | 276/600 [00:02<00:03, 101.09it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  48%|████▊     | 287/600 [00:02<00:03, 100.84it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  50%|████▉     | 298/600 [00:02<00:02, 101.87it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  52%|█████▏    | 309/600 [00:03<00:02, 101.02it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  53%|█████▎    | 320/600 [00:03<00:02, 101.01it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  55%|█████▌    | 331/600 [00:03<00:02, 101.52it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  57%|█████▋    | 342/600 [00:03<00:02, 102.12it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  59%|█████▉    | 353/600 [00:03<00:02, 102.07it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  61%|██████    | 364/600 [00:03<00:02, 102.49it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  62%|██████▎   | 375/600 [00:03<00:02, 102.80it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  64%|██████▍   | 386/600 [00:03<00:02, 102.30it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  66%|██████▌   | 397/600 [00:03<00:01, 103.06it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  68%|██████▊   | 408/600 [00:04<00:01, 102.08it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  70%|██████▉   | 419/600 [00:04<00:01, 100.80it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  72%|███████▏  | 430/600 [00:04<00:01, 100.20it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  74%|███████▎  | 441/600 [00:04<00:01, 99.63it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  75%|███████▌  | 451/600 [00:04<00:01, 99.13it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  77%|███████▋  | 461/600 [00:04<00:01, 98.55it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  78%|███████▊  | 471/600 [00:04<00:01, 98.45it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  80%|████████  | 481/600 [00:04<00:01, 98.19it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  82%|████████▏ | 491/600 [00:04<00:01, 96.46it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  84%|████████▎ | 501/600 [00:05<00:01, 95.42it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  85%|████████▌ | 511/600 [00:05<00:00, 95.90it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  87%|████████▋ | 521/600 [00:05<00:00, 96.87it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  88%|████████▊ | 531/600 [00:05<00:00, 96.79it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  90%|█████████ | 541/600 [00:05<00:00, 96.32it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  92%|█████████▏| 551/600 [00:05<00:00, 96.22it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  94%|█████████▎| 561/600 [00:05<00:00, 94.87it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  95%|█████████▌| 571/600 [00:05<00:00, 93.84it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  97%|█████████▋| 581/600 [00:05<00:00, 94.41it/s]
# Training UncertaintyPredictorExperiment (seed=4042):  98%|█████████▊| 591/600 [00:05<00:00, 94.15it/s]
# Training UncertaintyPredictorExperiment (seed=4042): 100%|██████████| 600/600 [00:06<00:00, 98.94it/s]
# Processing results (minimum length: 60 points)...
# Creating plots (steps: 50, skipping first 10 data points)...
# ============================================================
# MULTI-RUN EXPERIMENT COMPLETED!
# ============================================================
# Results saved to: exploration_methods_comparison_5runs_results.npy
# Plots saved to: exploration_methods_comparison_5runs.png and exploration_methods_combined_5runs.png
#
# SUMMARY STATISTICS (Final Values, 5 runs):
# --------------------------------------------------
#
# MSE:
#   Deterministic: 0.0070 ± 0.0001
#   Stochastic: 0.0691 ± 0.0015
#
# AMA:
#   Deterministic: -0.0022 ± 0.0005
#   Stochastic: -0.0020 ± 0.0020
#
# LPM:
#   Deterministic: 0.0013 ± 0.0007
#   Stochastic: 0.0007 ± 0.0023
